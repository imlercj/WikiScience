# %% [markdown]
# # Introduction: Downloading and Parsing Wikipedia Articles
#
# In this notebook, we will download all of the latest wikipedia articles and then parse them. We'll get to make use of a number of important data science techniques including:
#
# * Finding and retrieve online data
# * Parsing XML using a SAX parser
# * Parsing Mediawiki content using `mwparserfromhell`
# * Running operations in parallel using multiprocessing and multithreading
#
# The techniques covered here are broadly applicable in data science even though we are focusing on Wikipedia articles. Moveover, I'll be gathering all of the books articles for an ongoing project, but you can use the methods here to focus on any category of Wikipedia or even to search through all of the articles for specific content. Wikipedia is an incredibly rich source of human curated information, and learning how to work with it is a project in itself and also gives us more data for future data science projects.
#
# The code in this notebook is adapted from the excellent [Deep Learning Cookbook](http://shop.oreilly.com/product/0636920097471.do) by Douwe Osinga. The book is well worth it and you can access the Jupyter Notebooks [on GitHub](https://github.com/DOsinga/deep_learning_cookbook).

# %%
import requests

# Parsing HTML
from bs4 import BeautifulSoup

# File system management
import os

# %% [markdown]
# ## Searching for Wikipedia Download
#
# To start, we make a request to the [Wikimedia dumps](https://dumps.wikimedia.org/) of Wikipedia. We'll search through `enwiki` which has the [English language dumps](https://dumps.wikimedia.org/enwiki/) of wikipedia. This first request finds the available recent dumps and lists them. (A dump is a snapshot of all the existing information from a database).

# %%
base_url = 'https://dumps.wikimedia.org/enwiki/'
index = requests.get(base_url).text
soup_index = BeautifulSoup(index, 'html.parser')

# Find the links that are dates of dumps
dumps = [a['href'] for a in soup_index.find_all('a') if 
         a.has_attr('href')]
dumps
# Out:
# ['../',
#  '20201001/',
#  '20201020/',
#  '20201101/',
#  '20201120/',
#  '20201201/',
#  '20201220/',
#  '20210101/',
#  'latest/']

# %% [markdown]
# The next line of code finds the html content of the page for the dump made on the first of September. If there is a more recent version available, feel free to use that instead!

# %%
dump_url = base_url + '20210101/'

# Retrieve the html
dump_html = requests.get(dump_url).text
dump_html[:10]
# Out:
# '<!DOCTYPE '

# %% [markdown]
# It may be helpful to go to https://dumps.wikimedia.org/enwiki/20180901/ to see the available downloads. If you wanted to download the files by hand, you could do that, but we'll accomplish it programmatically.
#
# Next we will parse through the html text to find the files we want to download.

# %% [markdown]
# ### Deciding What to Download
#
# We will focus only on the most recent version of the articles themselves. It is possible to get the past history of articles, the edits, the discussion, and other metadata, but the articles themselves provide us with more than enough data!
#
# For more information on the available downloads, take a look at the [Wikimedia dump](https://dumps.wikimedia.org/) or on [Wikipedia itself](https://en.wikipedia.org/wiki/Wikipedia:Database_download#English-language_Wikipedia).
#
# The most recent revision of every single article (what we are after) is available in a single compressed file as `pages-articles.xml.bz2`. However, we'll download the articles in smaller chunks so that we can then process them in parallel (which we'll see later). The single file - which is compressed XML (using bz2) - is over 15 GB while the smaller chunks - of which there are 55 - are several hundred megabytes each also compressed XML.
#
# If you only want to find a specific article, then the `pages-article-multistream.xml.bz2` may be a better choice. There is an `index` for the multistream version that means you can locate a specific article within the compressed file without having to search through the entire file. For more information refer to the "Should I get Multistream?" section on [this Wikipedia page](https://en.wikipedia.org/wiki/Wikipedia:Database_download#).
#
# To find all the individual files, we'll search through the html from the dump identified earlier. We'll look for any files that have `pages_articles` in the text. To parse through html (or other markup languages), we can use Beautiful Soup. This makes searching for particular tags and classes (such as `file` below) very efficient. If you are doing any web scraping, this will be a very useful library to learn!

# %%
# Convert to a soup
soup_dump = BeautifulSoup(dump_html, 'html.parser')

# Find li elements with the class file
soup_dump.find_all('li', {'class': 'file'}, limit = 10)[:4]
# Out:
# [<li class="file"><a href="/enwiki/20210101/enwiki-20210101-pages-articles-multistream.xml.bz2">enwiki-20210101-pages-articles-multistream.xml.bz2</a> 17.8 GB</li>,
#  <li class="file"><a href="/enwiki/20210101/enwiki-20210101-pages-articles-multistream-index.txt.bz2">enwiki-20210101-pages-articles-multistream-index.txt.bz2</a> 218.1 MB</li>,
#  <li class="file"><a href="/enwiki/20210101/enwiki-20210101-pages-articles-multistream1.xml-p1p41242.bz2">enwiki-20210101-pages-articles-multistream1.xml-p1p41242.bz2</a> 233.8 MB</li>,
#  <li class="file"><a href="/enwiki/20210101/enwiki-20210101-pages-articles-multistream-index1.txt-p1p41242.bz2">enwiki-20210101-pages-articles-multistream-index1.txt-p1p41242.bz2</a> 221 KB</li>]

# %% [markdown]
# This has given us all of the available files for download in the September 1 dump of Wikipedia. Now we want to limit to only the files containing `pages-articles` to get only the recent versions of the articles.

# %%
files = []

# Search through all files
for file in soup_dump.find_all('li', {'class': 'file'}):
    text = file.text
    # Select the relevant files
    if 'pages-articles' in text:
        files.append((text.split()[0], text.split()[1:]))
        
files[:5]
# Out:
# [('enwiki-20210101-pages-articles-multistream.xml.bz2', ['17.8', 'GB']),
#  ('enwiki-20210101-pages-articles-multistream-index.txt.bz2', ['218.1', 'MB']),
#  ('enwiki-20210101-pages-articles-multistream1.xml-p1p41242.bz2',
#   ['233.8', 'MB']),
#  ('enwiki-20210101-pages-articles-multistream-index1.txt-p1p41242.bz2',
#   ['221', 'KB']),
#  ('enwiki-20210101-pages-articles-multistream2.xml-p41243p151573.bz2',
#   ['315.7', 'MB'])]

# %% [markdown]
# We only want the partitioned files so we can further refine our selection to those with `xml-p`.

# %%
files_to_download = [file[0] for file in files if '.xml-p' in file[0]]
files_to_download[-5:]
# Out:
# ['enwiki-20210101-pages-articles25.xml-p60025656p61525655.bz2',
#  'enwiki-20210101-pages-articles25.xml-p61525656p62585850.bz2',
#  'enwiki-20210101-pages-articles26.xml-p62585851p63975909.bz2',
#  'enwiki-20210101-pages-articles27.xml-p63975910p65475909.bz2',
#  'enwiki-20210101-pages-articles27.xml-p65475910p66265382.bz2']

# %% [markdown]
# I'm not sure what the `p` numbers mean at the end of the file name. It must have something to do with the partitioning of the data. At first I thought it was the number of articles in the partition, but the English language Wikipedia only has 5.8 million article and these numbers go up to 58 million. If we subtract the second number from the first, the most common number is 1.5 million. Maybe this has something to do with the number of bytes in the file? I'm not sure, but I would appreciate if someone would let met know.

# %% [markdown]
# ## Download Wikipedia Data
#
# Now we need to actually download the data. This can be done using the keras `get_file` utility which downloads the specified file at the specified url. If we already have the entire dataset downloaded, then we don't want to download it again! For that reason we first use a check to see if the data exists.
#
# The default download directory for keras is `~/.keras/datasets`. I already had the dataset downloaded, but the download will take around 150 minutes and requires at least 15 GB of disk space.

# %%
import sys
import os
from glob import glob

keras_home = '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream*.bz2'

# %%
files_list = glob(keras_home)

# %%
data_paths = []
file_info = []

# Iterate through each file
for path in files_list:
    
    data_paths.append(path)
    # Find the file size in MB
    file_size = os.stat(path).st_size / 1e6

    # Find the number of articles
    file_number = int(path.split('p')[-1].split('.')[-2]) - int(path.split('p')[-2])
    file_info.append((path.split('-')[-1], file_size, file_number))

# %% [markdown]
# What is the largest file? We can use `sorted` to sort by the file size.

# %%
sorted(files_list)
# Out:
# ['/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream1.xml-p10p30302.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream10.xml-p2336425p3046511.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream11.xml-p3046517p3926861.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream12.xml-p3926864p5040435.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream13.xml-p5040438p6197593.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream14.xml-p6197599p7697599.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream14.xml-p7697599p7744799.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream15.xml-p7744803p9244803.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream15.xml-p9244803p9518046.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream16.xml-p11018059p11539266.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream16.xml-p9518059p11018059.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream17.xml-p11539268p13039268.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream17.xml-p13039268p13693066.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream18.xml-p13693075p15193075.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream18.xml-p15193075p16120541.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream19.xml-p16120548p17620548.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream19.xml-p17620548p18754723.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream2.xml-p30304p88444.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream20.xml-p18754736p20254736.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream20.xml-p20254736p21222156.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream21.xml-p21222161p22722161.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream21.xml-p22722161p23927980.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream22.xml-p23927984p25427984.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream22.xml-p25427984p26823658.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream23.xml-p26823661p28323661.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream23.xml-p28323661p29823661.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream23.xml-p29823661p30503448.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream24.xml-p30503454p32003454.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream24.xml-p32003454p33503454.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream24.xml-p33503454p33952815.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream25.xml-p33952817p35452817.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream25.xml-p35452817p36952817.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream25.xml-p36952817p38067198.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream26.xml-p38067204p39567204.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream26.xml-p39567204p41067204.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream26.xml-p41067204p42567204.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream26.xml-p42567204p42663461.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream27.xml-p42663464p44163464.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream27.xml-p44163464p45663464.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream27.xml-p45663464p47163464.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream27.xml-p47163464p48663464.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream27.xml-p48663464p50163464.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream27.xml-p50163464p51663464.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream27.xml-p51663464p53163464.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream27.xml-p53163464p54663464.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream27.xml-p54663464p56163464.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream27.xml-p56163464p57663464.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream27.xml-p57663464p59163464.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream27.xml-p59163464p60663464.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream27.xml-p60663464p60933434.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream3.xml-p88445p200507.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream4.xml-p200511p352689.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream5.xml-p352690p565312.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream6.xml-p565314p892912.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream7.xml-p892914p1268691.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream8.xml-p1268693p1791079.bz2',
#  '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream9.xml-p1791081p2336422.bz2']

# %%
sorted(file_info, key = lambda x: x[1], reverse = True)[:5]
# Out:
# [('p6197599p7697599.bz2', 428.298525, 1500000),
#  ('p3926864p5040435.bz2', 425.292935, 1113571),
#  ('p5040438p6197593.bz2', 421.178023, 1157155),
#  ('p3046517p3926861.bz2', 409.551794, 880344),
#  ('p7744803p9244803.bz2', 404.636836, 1500000)]

# %% [markdown]
# These sizes are in MB. It looks like the largest files are about 400 MB compressed.

# %% [markdown]
# Again, I don't know what the numbers after the p mean, but the most common difference between the first and second is 1_500_000.

# %%
print(f'There are {len(file_info)} partitions.')
# Out:
# There are 57 partitions.

# %% [markdown]
# How about putting this info into a dataframe to plot the file sizes?

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
file_df = pd.DataFrame(file_info, columns = ['file', 'size (MB)', 'articles']).set_index('file')
file_df['size (MB)'].plot.bar(color = 'red', figsize = (12, 6));

# %% [markdown]
# Total there are 5.7 million articles contained in these files. In a way, it's surprising that the extent of all human knowledge (okay I'm exaggerating somewhat) is now contained on our computer!
#
# #### Size of Wikipedia
#
# For some interesting reading, check out the following Wikipedia Articles:
#
# * [Size of Wikipedia](https://en.wikipedia.org/wiki/Wikipedia:Size_of_Wikipedia)
# * [Modelling Growth of Wikipedia](https://en.wikipedia.org/wiki/Wikipedia:Modelling_Wikipedia%27s_growth#Data_set_for_number_of_articles)
# * [Size Comparisons of Wikipedia to other Encyclopedias](https://en.wikipedia.org/wiki/Wikipedia:Size_comparisons)

# %%
print(f"The total size of files on disk is {file_df['size (MB)'].sum() / 1e3} GB")
# Out:
# The total size of files on disk is 17.142520231 GB

# %% [markdown]
# Again, we could download this all at once with the `pages-articles.xml.bz2` file, but then we would have to parse it sequentially which takes ages. Instead, because we have partitioned data, we can iterate over the files in parallel and process 16 at a time (as we'll see later).

# %% [markdown]
# ## Parsing the Data
#
# Together, the files take up 15.4 GB. Decompressed as xml, it's close to 50 GB. We could decompress each file into XML and then parse through it, but we can also parse through a decompressed file iteratively one line at a time. If we are concered about disk space, this is a better option. Working through the compressed file one line at a time also might be the only option in cases where the individual files are too large to fit in memory.
#
# We'll start by working through one of the files and then develop functions that we can run on all of the files. Because we downloaded the data in chunks, we'll be able to parallelize the parsing operations.
#
# ### Iterating through Compressed Files
#
# To get started, make sure you have `bzcat` installed on your system. The [`bzcat` utility] (http://www.qnx.com/developers/docs/6.5.0SP1.update/com.qnx.doc.neutrino_utilities/b/bzcat.html) is a command line program that decompresses a bz2 compressed file and sends the contents to standard out. To go through the files one line at a time, we simply iterate over the command to decompress the file. We call the `bzcat` command using `subprocess` which is often used to execute system commands in Python.
#
# Another option for decompressing the file is `bz2`. However, in tests (see below), I found this to be much slower than `bzcat`.

# %%
import bz2
import subprocess

data_path = data_paths[15]
data_path
# Out:
# '/Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream26.xml-p42567204p42663461.bz2'

# %% [markdown]
# The `subprocess` + `bzcat` approach is nearly twice as fast. Let's run this again and see what kind of data we have.

# %%
lines = []

for i, line in enumerate(subprocess.Popen(['bzcat'], 
                         stdin = open(data_path), 
                         stdout = subprocess.PIPE).stdout):
  
    lines.append(line)
    if i > 5e5:
        break

# %% [markdown]
# Here we have a complete article. We could go through each file and extract out the articles using regular expressions, but that would be extremely inefficient. Instead, we'll use an XML parser to find the article text that we then will use _another_ parser to extract information from.

# %% [markdown]
# # Parsing Approach
#
# In order to get useful information from this data, we have to parse it on two levels.
#
# 1. Extract the titles and article text from the XML
# 2. Extract relevant information from the article text

# %% [markdown]
# ## Parsing XML
#
# To solve the first problem, we'll use a tool purpose built for the task of parsing XML, SAX: The Simple API for XML. [The documentation](http://pyxml.sourceforge.net/topics/howto/section-SAX.html) is a little difficult to follow, but the basic idea is that we can use SAX to search through the XML and select elements based on the tag. (If you need an introduction to XML, I'd highly recommend starting [here](https://www.w3schools.com/xml/default.asp)).
#
# For example, if we have the follow XML element, we want to extract the text that occurs between the `<title>` tags:
#
# `<title>Carroll Knicely</title>`
#
# Likewise, if we have the content of an article like below, we want to extract the text that occurs between the `<text>` tags.
#
# ```XML
# <text xml:space="preserve">\'\'\'Carroll F. Knicely\'\'\' (born c. 1929 in [[Staunton, Virginia]] - died November 2, 2006 in [[Glasgow, Kentucky]]) was [[Editing|editor]] and [[Publishing|publisher]] of the \'\'[[Glasgow Daily Times]]\'\' for nearly 20 years (and later, its owner) and served under three [[Governor of Kentucky|Kentucky Governors]] as commissioner and later Commerce Secretary.\n'
# </text>
# ```
#
# We'll use the SAX XML parser to do exactly that: find the titles and text content of the articles. Then, we can pass the text to another parser to extract information from the article.
#
# Explaining how SAX works is a little more difficult than just showing, so I'll present the code and show some examples. A SAX parser requires a content handler, which is the only code we need to write.
#
# (Beautiful Soup can also be used for parsing XMl. However, it requires reading in an entire file at a time in order to build a Document Object Model (DOM). For our use case, the SAX parser works better because it parser XML sequentially which means we don't need to read the whole file into memory. If you want to look at the Beautiful Soup approach, you can refer to [this article.](http://www2.hawaii.edu/~takebaya/cent110/xml_parse/xml_parse.html) or the [BeautifulSoup documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) which includes information on XML parsing using the library.)

# %%
import xml.sax

class WikiXmlHandler(xml.sax.handler.ContentHandler):
    """Content handler for Wiki XML data using SAX"""
    def __init__(self):
        xml.sax.handler.ContentHandler.__init__(self)
        self._buffer = None
        self._values = {}
        self._current_tag = None
        self._pages = []

    def characters(self, content):
        """Characters between opening and closing tags"""
        if self._current_tag:
            self._buffer.append(content)

    def startElement(self, name, attrs):
        """Opening tag of element"""
        if name in ('title', 'text', 'timestamp'):
            self._current_tag = name
            self._buffer = []

    def endElement(self, name):
        """Closing tag of element"""
        if name == self._current_tag:
            self._values[name] = ' '.join(self._buffer)

        if name == 'page':
            self._pages.append((self._values['title'], self._values['text']))

# %% [markdown]
# The Content handler looks for certain start tags, and when it finds one, it adds characters to the buffer until it encouters the same end tag. Then it saves the buffer content to a dictionary with the tag as key. We are overriding a few of the default SAX `ContentHandler` methods in order to do what we want: find the titles and texts in the XML.
#
# The text of Wikipedia articles starts and ends with the `<text>` tag and the entire article starts and ends with the `<page>` tag. The `<timestamp>` tag records the last edit of the page.
#
# Next, we need to create a `handler` object of the `WikiXMLHandler` class. Then we pass the handler in as the content handler to a SAX `parser`.

# %%
# Content handler for Wiki XML
handler = WikiXmlHandler()

# Parsing object
parser = xml.sax.make_parser()
parser.setContentHandler(handler)

handler._pages
# Out:
# []

# %% [markdown]
# Let's work through a single article. We `feed` in one line of XML at a time to the `parser`. It searches the XML for the tags using the methods in the handler. The correct data is then stored in the handler (later we'll pass the `text` on to another parser).

# %%
for l in lines[0:-100]:
    try:
        if parser.feed(l.decode('utf-8')):
            print(parser.feed(l.decode('utf-8')))
    except:
        pass #print('error', l.decode('utf-8'))

# %%
handler._pages[10]
# Out:
# ('Category:Sculptures in New York (state)',
#  '{{commonscat|Sculptures in New York (state)}} \n {{-}} \n [[Category:Art in New York (state)|S]] \n [[Category:Sculptures in the United States by state|New York]]')

# %% [markdown]
# We have successfully extracted one page! Once we have the page text, we need to process it as well to find the information we want. We'll write that function next. First, let's see this process again, this time finding three different articles.

# %%
# Object for handling xml
handler = WikiXmlHandler()

# Parsing object
parser = xml.sax.make_parser()
parser.setContentHandler(handler)

for i, line in enumerate(subprocess.Popen(['bzcat'], 
                         stdin = open(data_path), 
                         stdout = subprocess.PIPE).stdout):
    parser.feed(line)
    
    # Stop when 3 articles have been found
    if len(handler._pages) > 2:
        break
        
print([x[0] for x in handler._pages])
# Out:
# ['Kim Hyeon-Woo', 'Lee Se-Yeol', 'Marko Virtanen']

# %% [markdown]
# The next step is to process the actual text of the article. For this, we will turn to the `mwparserfromhell` library. [This library](https://github.com/earwig/mwparserfromhell) is custom made for parsing `MediaWiki` wikicode which is a standard that includes Wikipedia articles. [MediaWiki](https://www.mediawiki.org/wiki/MediaWiki) is used by Wikipedia and numerous other projects and provides a relatively standardized template for creating wiki pages. Thanks to this standardization, we can using a custom built parser to go through the articles.

# %% [markdown]
# ## Parsing Articles
#
# The text of the articles themselves is processed using the `mwparserfromhell`. Although the text may simple look like a Python string, there is far more information contained in the formatting of the `text` than just the information we can see.
#
# First we'll find a number of articles using the `WikiXmlHandler` and a SAX parser.

# %%
# Object for handling xml
handler = WikiXmlHandler()

# Parsing object
parser = xml.sax.make_parser()
parser.setContentHandler(handler)

for i, line in enumerate(subprocess.Popen(['bzcat'], 
                         stdin = open(data_path), 
                         stdout = subprocess.PIPE).stdout):
    parser.feed(line)
    
    # Stop when 50 articles have been found
    if len(handler._pages) > 50:
        break

# %% [markdown]
# To create a `wiki` representation of the text, we pass the Wikipedia article text to the `mwparserfromhell`.

# %%
import mwparserfromhell 

print(handler._pages[5][0])

# Create the wiki article
wiki = mwparserfromhell.parse(handler._pages[5][1])
# Out:
# 2014–15 Northern Illinois Huskies men's basketball team

# %% [markdown]
# We'll work through the article for KENZ (FM). It might be helpful to pull up the [Wikipedia page alongside](https://en.wikipedia.org/wiki/KENZ_(FM)) so you can see what is happening.

# %%
print(type(wiki))
wiki[:100]
# Out:
# <class 'mwparserfromhell.wikicode.Wikicode'>
# '{{Infobox NCAA team season \n |Mode              = Basketball \n |Year              = 2014–15 \n |Prev '

# %% [markdown]
# This looks like a normal string, but in fact, it's a `mwparserfromhell.wikicode.Wikicode` object with many different methods for sorting through the content.
#
# ### Wikicode Search Methods
#
# For example, we can find all the internal links (those that go to other wikipedia pages) using `wiki.filter_wikilinks()`. This will give us the `title` of the Wikipedia article linked to as well as the `text` of the link. We'll extract just the titles of the articles.

# %%
wikilinks = [x.title for x in wiki.filter_wikilinks()]
print(f'There are {len(wikilinks)} wikilinks.')
wikilinks[:5]
# Out:
# There are 107 wikilinks.
# ['Mark Montgomery (basketball)',
#  'Convocation Center (Northern Illinois University)',
#  'Northern Illinois University',
#  "2014–15 NCAA Division I men's basketball season",
#  'Mark Montgomery (basketball)']

# %% [markdown]
# We didn't get the discussion or the edits around the articles, so we won't be able to find this information. However, if you do decide to grab comments, edits, revisions, etc., you can use `mwparserfromhell` to extract all of these.

# %% [markdown]
# To figure out everything you can do with `mwparserfromhell`, [read the docs](https://mwparserfromhell.readthedocs.io/en/latest/).

# %% [markdown]
# We can find the external links (those that go outside of Wikipedia).

# %%
external_links = [(x.title, x.url) for x in wiki.filter_external_links()]
print(f'There are {len(external_links)} external links.')
external_links[:5]
# Out:
# There are 2 external links.
# [(None, 'http://www.bcsn.tv/news_article/show/483248'),
#  (None,
#   'https://web.archive.org/web/20150225052545/http://www.bcsn.tv/news_article/show/483248')]

# %% [markdown]
# We can also search through the text for specific words.

# %%
contemporary = wiki.filter(matches = 'bask')
contemporary[1], type(contemporary[1])
# Out:
# (' Basketball \n ', mwparserfromhell.nodes.text.Text)

# %% [markdown]
# Each time we select a different part of the `wiki`, we get back another `wiki` object with different methods. Although it might look like we are getting strings, there is far more we can do with the `wiki` than we could with a string.

# %% [markdown]
# If you want to get a cleaner version of just the text, you can call `wiki.strip_code()` and then add another `strip`.

# %%
wiki.strip_code().strip()[:100]
# Out:
# "The 2014–15 Northern Illinois Huskies men's basketball team represented Northern Illinois University"

# %% [markdown]
# There's quite a bit more you can do with this library, so explore the options if you have a project in mind.

# %% [markdown]
# ## Article Templates
#
# Since I'm looking to collect all the books on Wikipedia, I'll need a method to filter articles to only those that are about books. The easiest way to filter articles to a category (at least that I've found) is through the use of templates. These are standardized formats for information. For example, one template on the `KENZ (FM)` radio station page looks like this:
#
# ![Radio Station Infobox](https://github.com/WillKoehrsen/wikipedia-data-science/blob/master/images/radio_template.PNG?raw=true)
#
# This particular template is called an `Infobox`.
#
# ### Infobox Templates
#
# There are many different infoboxes templates, each one for a different category such as films or books. __The easiest way to filter articles to one category is by using the `Infobox` template for that category__.
# You can read about infoboxes [here](https://en.wikipedia.org/wiki/Help:Infobox) or look at the list [here](https://en.wikipedia.org/wiki/Wikipedia:List_of_infoboxes). For example, if we want to find articles about books, we filter the article for the template `Infobox book`.
#
# Let's take a look at the templates for this article.

# %%
templates = wiki.filter_templates()
print(f'There are {len(templates)} templates.')
for template in templates:
    print(template.name)
# Out:
# There are 61 templates.
# Infobox NCAA team season
#
# 2014–15 Mid-American Conference men's basketball standings
# CBB roster/Header
# CBB roster/Player
# CBB roster/Player
# CBB roster/Player
# CBB roster/Player
# CBB roster/Player
# CBB roster/Player
# CBB roster/Player
# CBB roster/Player
# CBB roster/Player
# CBB roster/Player
# CBB roster/Player
# CBB roster/Player
# CBB roster/Player
# CBB roster/Player
# CBB roster/Player
# CBB roster/Footer
#
# college
# college
# college
# college
# CBB schedule start
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# cite web
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule entry
#
# CBB schedule end
#
# reflist
# Northern Illinois Huskies men's basketball navbox
# DEFAULTSORT:2014-15 Northern Illinois Huskies men's basketball Team

# %% [markdown]
# There are a number of different templates. In this case, the Infobox is called `Infobox radio station`. If we wanted to find all of the radio station articles, then the easiest way would be to search every article for this template. We can search for a specific template within an article as below.

# %%
infobox = wiki.filter_templates(matches = 'Infobox NCAA team season ')[0]
infobox
# Out:
# '{{Infobox NCAA team season \n |Mode              = Basketball \n |Year              = 2014–15 \n |Prev year         = 2013–14 \n |Next year         = 2015–16 \n |Team              = Northern Illinois Huskies \n |Image             = Northern Illinois Huskies basketball wordmark.svg \n |ImageSize         = 250 \n |Conference        = Mid-American Conference \n |Division          = West Division \n |ShortConference   = MAC \n |CoachRank         = \n |APRank            = \n |Record            = 14–16 \n |ConfRecord        = 8–10 \n |HeadCoach         = [[Mark Montgomery (basketball)|Mark Montgomery]] \n |HCYear            = 4th \n |AsstCoach1        = Jon Borovich \n |AsstCoach2        = Lou Dawkins \n |AsstCoach3        = Jason Larson \n |AsstCoach4        = \n |StadiumArena      = [[Convocation Center (Northern Illinois University)|Convocation Center]] \n |Champion          =  \n |BowlTourney       = \n |BowlTourneyResult = \n }}'

# %% [markdown]
# The attributes of the infobox can be accessed and put into a dictionary using the `name` and the `value`. To clean things up, we first strip the code and then strip whitespace and escape characters.

# %%
information = {param.name.strip_code().strip(): param.value.strip_code().strip() for param in infobox.params}
information
# Out:
# {'Mode': 'Basketball',
#  'Year': '2014–15',
#  'Prev year': '2013–14',
#  'Next year': '2015–16',
#  'Team': 'Northern Illinois Huskies',
#  'Image': 'Northern Illinois Huskies basketball wordmark.svg',
#  'ImageSize': '250',
#  'Conference': 'Mid-American Conference',
#  'Division': 'West Division',
#  'ShortConference': 'MAC',
#  'CoachRank': '',
#  'APRank': '',
#  'Record': '14–16',
#  'ConfRecord': '8–10',
#  'HeadCoach': 'Mark Montgomery',
#  'HCYear': '4th',
#  'AsstCoach1': 'Jon Borovich',
#  'AsstCoach2': 'Lou Dawkins',
#  'AsstCoach3': 'Jason Larson',
#  'AsstCoach4': '',
#  'StadiumArena': 'Convocation Center',
#  'Champion': '',
#  'BowlTourney': '',
#  'BowlTourneyResult': ''}

# %% [markdown]
# The `Infobox` templates provide us with a consistent method for finding a category of article. We simply need to search the article text for the `Infobox` of the category of article we want.
#
# Moreover, the information in the template could be useful for say building a set of features in a predictive model. In this project, we aren't going to be working with the text of the articles - that's an entirely separate undertaking - but we can use information such as that found in the `Infobox` or the `wikilinks` as structured data.
#
# ## Searching for a Category
#
# Now that we have an understanding of how to parse an article and find articles belonging to a certain category, we can start searching for what we want: all the books on Wikipedia! The books can be identified because they use an Infobox book template.
#
# ![Infobox book](https://github.com/WillKoehrsen/wikipedia-data-science/blob/master/images/book_template.PNG?raw=true)
#
# We simply have to filter the article text for the `Infobox book` template, and if it's present, store the information. If not, then we move to the next article. The function below is designed to find and return articles that have a specified template.

# %%
import re

def process_article(title, text, timestamp, template = 'Infobox musical artist'): # 'Infobox book'
    """Process a wikipedia article looking for template"""
    # Create a parsing object
    wikicode = mwparserfromhell.parse(text)
    
    # Search through templates for the template
    matches = wikicode.filter_templates(matches = template)
    
    # Filter out errant matches
    matches = [x for x in matches if x.name.strip_code().strip().lower() == template.lower()]
    
    if len(matches) >= 1:
        # template_name = matches[0].name.strip_code().strip()

        # Extract information from infobox
        properties = {param.name.strip_code().strip(): param.value.strip_code().strip() 
                      for param in matches[0].params
                      if param.value.strip_code().strip()}
        
        # Extract internal wikilinks
        wikilinks = [x.title.strip_code().strip() for x in wikicode.filter_wikilinks()]

        # Internal links in infobox
        infolinks = {param.name.strip_code().strip():[link.title.strip_code().strip() for link in param.value.filter_wikilinks()] for param in matches[0].params}
        # Find approximate length of article
        text_length = len(wikicode.strip_code().strip())

        return (title, properties, wikilinks, infolinks, timestamp, text_length)

# %%
template = 'Infobox NCAA team season'
# Create a parsing object
wikicode = mwparserfromhell.parse(wiki)

# Search through templates for the template
matches = wikicode.filter_templates(matches = template)

# Filter out errant matches
matches = [x for x in matches if x.name.strip_code().strip().lower() == template.lower()]

if len(matches) >= 1:
    # template_name = matches[0].name.strip_code().strip()

    # Extract information from infobox
    properties = {param.name.strip_code().strip(): param.value.strip_code().strip() 
                  for param in matches[0].params
                  if param.value.strip_code().strip()}

# %%
r = process_article('KENZ (FM)', wiki, None, template = 'Infobox NCAA team season')
r[0], r[1], r[3]
# Out:
# ('Infobox NCAA team season',
#  {'Mode': 'Basketball',
#   'Year': '2014–15',
#   'Prev year': '2013–14',
#   'Next year': '2015–16',
#   'Team': 'Northern Illinois Huskies',
#   'Image': 'Northern Illinois Huskies basketball wordmark.svg',
#   'ImageSize': '250',
#   'Conference': 'Mid-American Conference',
#   'Division': 'West Division',
#   'ShortConference': 'MAC',
#   'Record': '14–16',
#   'ConfRecord': '8–10',
#   'HeadCoach': 'Mark Montgomery',
#   'HCYear': '4th',
#   'AsstCoach1': 'Jon Borovich',
#   'AsstCoach2': 'Lou Dawkins',
#   'AsstCoach3': 'Jason Larson',
#   'StadiumArena': 'Convocation Center'},
#  {'Mode': [],
#   'Year': [],
#   'Prev year': [],
#   'Next year': [],
#   'Team': [],
#   'Image': [],
#   'ImageSize': [],
#   'Conference': [],
#   'Division': [],
#   'ShortConference': [],
#   'CoachRank': [],
#   'APRank': [],
#   'Record': [],
#   'ConfRecord': [],
#   'HeadCoach': ['Mark Montgomery (basketball)'],
#   'HCYear': [],
#   'AsstCoach1': [],
#   'AsstCoach2': [],
#   'AsstCoach3': [],
#   'AsstCoach4': [],
#   'StadiumArena': ['Convocation Center (Northern Illinois University)'],
#   'Champion': [],
#   'BowlTourney': [],
#   'BowlTourneyResult': []})

# %% [markdown]
# ### Modified Content Handler
#
# To parse the text from each article and search for the specified template, we slightly modify the `Handler` class. This time, in the `endElement` function, if the article ends (the tag is `page`) then we send the title and the contents (`text`) to the `process_article` function. This function will return either nothing if it doesn't find a book, or the book properties, Wikilinks, and external links if it does find a book. These will be added as a list to the `handler`.

# %%
class WikiXmlHandler(xml.sax.handler.ContentHandler):
    """Parse through XML data using SAX"""
    def __init__(self):
        xml.sax.handler.ContentHandler.__init__(self)
        self._buffer = None
        self._values = {}
        self._current_tag = None
        self._books = []
        self._article_count = 0
        self._non_matches = []

    def characters(self, content):
        """Characters between opening and closing tags"""
        if self._current_tag:
            self._buffer.append(content)

    def startElement(self, name, attrs):
        """Opening tag of element"""
        if name in ('title', 'text', 'timestamp'):
            self._current_tag = name
            self._buffer = []

    def endElement(self, name):
        """Closing tag of element"""
        if name == self._current_tag:
            self._values[name] = ' '.join(self._buffer)

        if name == 'page':
            self._article_count += 1
            # Search through the page to see if the page is a book
            book = process_article(**self._values, template = 'Infobox musical artist')
            # Append to the list of books
            if book:
                self._books.append(book)

# %% [markdown]
# To use this for a different category of articles on Wikipedia, all you need to do is change the template. You can also alter the `process_article` function if you want to return different information for each article.

# %% [markdown]
# Now let's see if this works. The code below stops when we've found 3 books.

# %%
# Object for handling xml
handler = WikiXmlHandler()

# Parsing object
parser = xml.sax.make_parser()
parser.setContentHandler(handler)

for i, line in enumerate(subprocess.Popen(['bzcat'], 
                         stdin = open(data_path), 
                         stdout = subprocess.PIPE).stdout):
    parser.feed(line)
    
    # Stop when 3 articles have been found
    if len(handler._books) > 2:
        break
        
print(f'Searched through {handler._article_count} articles to find 3 books.')
# Out:
# Kim Hyeon-Woo
# Lee Se-Yeol
# Marko Virtanen
# João de Oliveira
# File:David and Goliath -1700s.jpg
# 2014–15 Northern Illinois Huskies men's basketball team
# Category:Scottish people of Russian-Jewish descent
# Kim Jin-Hyeok
# Sherri Jean Tucker
# Yellow fat-tail scorpion
# Category:Sculptures in New York (state)
# Kim Jin-Cheol
# File:Pressure (play).jpg
# Gavin Turek
# Hypoxis juncea
# Sishen–Saldanha Orex line
# Mathews Mr Easy
# 2014–15 Toledo Rockets men's basketball team
# Kim Young-Nam
# Falcon 9 flight 11
# ADT Event Center
# Kim Ji-Hun (wrestler)
# Blitz kids
# Little River Turnpike Bridge
# Category:Mathews aircraft
# Yellow fattail scorpion
# Anssi Laine
# Template:Taxonomy/Corallus
# Claude Koutob
# Nikolay Valeryevich Markov
# Kim Ik-Hee
# Falcon 9 flight 12
# Category:Sculptures in Massachusetts
# Ryu Han-Su
# Tampa Shores, Florida
# Tampa Shores, FL
# Little Shasta Church
# Category:Filton
# Mr Easy
# Mr. Easy
# Mathews Mr. Easy
# Falcon 9 flight 13
# Donyi-Poloism
# Category:Films scored by Ilaiyaraaja
# Take Me to Church
# Donyipoloism
# Falcon 9 flight 14
# Category:Airdrieonians F.C. (1878) wartime guest players
# Category:Scottish people of Polish-Jewish descent
# Falcon 9 flight 15
# Template:Did you know nominations/Daniel Suárez (racing driver)
# You In-Tak
# File:Sanford-Brown Logo.jpg
# Category:Sculptures in North Carolina
# Philatelic Exporter
# Kim Eui-Kon
# File:Goodfilenames.png
# Jun Dae-Je
# Joe Falcón
# Jeon Hae-Sup
# David Holden (screenwriter)
# Edward Surtz
# Lee Yeun-Ik
# Moon Jin-Ju
# Park Byung-Hyo
# Flowers in the Attic (TV Movie 2014)
# The Casual Vacancy (Television series)
# Lee Jae-Suk
# File:Yokosuka MXY6 Glider.jpg
# Kim Young-Jun
# Kim Weon-Kee
# Flowers in the Attic (TV movie)
# Kim Jong-Kyu
# Kim Jong-Dae
# An Jae-Won
# An Dae-Hyun
# An Chun-Young
# Athletics at the 1999 All-Africa Games – Women's heptathlon
# Analia Saban
# Tenmile, Coos County, Oregon
# Aizik Homiler
# Boxers Tour
# Donax canniformis
# Template:Attached KML/Flatlands Avenue
# Category:Chilean people of Latvian-Jewish descent
# Category:Hong Kong portal did you know
# Wikipedia:WikiProject Spam/LinkReports/thedreamtravelgroup.co.uk
# Category:Chilean people of Latvian descent
# Wikipedia:WikiProject Spam/LinkReports/modwedding.com
# Little Saigon, Orange County
# Category:Latvian emigrants to Chile
# Colt M1847 Walker
# Wikipedia:WikiProject Spam/LinkReports/cokincokine.com
# Goblins in the Castle
# 2014 Indian general election in Andhra Pradesh
# Template:Attached KML/Manhattan Avenue (Brooklyn)
# Colt M1836 Patterson
# Wikipedia:Miscellany for deletion/User:Synsepalum2013/sandbox/Voice to skull
# J. Ellis Rodley
# Naples in Green and Blue
# Category:People of Mexican-Jewish descent
# ActiveState Komodo
# Napoli verde-blu
# Andrea Ekonomi
# John Ellis Rodley
# 24th Army Tank Brigade
# Template:Granada CF managers
# Chris McGurk
# Template:Attached KML/Vanderbilt Avenue
# Halopegia
# Belmont Filmhouse, Aberdeen
# Amman Koil Kizhakale
# The Belmont Filmhouse, Aberdeen
# Paul Gleeson (magician)
# Lisa Lapinski
# Sotos
# CHRIS MCGURK
# Louis L. Martz
# La Madrastra (2005 TV series)
# Amman Koil Thiruvizha
# La madrastra
# British 87th Armoured Brigade (Dummy Tanks)
# Robert Cyril Morton Jenkins
# British 74th Armoured Brigade (Dummy Tanks)
# Aristocrat fashion
# Frank Richardson (policeman)
# Template:Staten Island Streets
# Shen Zhong
# Fredrik Møller
# Template:Brooklyn Streets
# New Gothic Art
# Wikipedia:Categories for discussion/Discussions awaiting closure
# Harry Heath
# Argile Smith
# Alexei Vasilevsky (figure skater)
# Alexei Vasilevsky
# Wikipedia:Templates for discussion/Log/2014 April 24
# Blair Athol, Queensland
# Wikipedia:Files for deletion/2014 April 24
# Wikipedia:Deletion review/Log/2014 April 24
# Wikipedia:Possibly unfree files/2014 April 24
# Marondera District
# Armando Fizzarotti
# Dennis O'Brien (policeman)
# Edward Grey (policeman)
# Category:Films directed by Armando Fizzarotti
# Nightfever
# Richard Fallon (policeman)
# Ed Long (cricketer)
# File:NESIsland.gif
# Lu Deming
# Kalevala (corvette)
# John Coughlin (policeman)
# Maker's plate
# Members of the Victorian Legislative Assembly, 1894–1897
# James Farrell (policeman)
# John Cullen (policeman)
# Haumania
# Anal Kaatru
# Petronella Barker (actress born 1965)
# John C. Ferguson (Sinologist)
# UFO researcher
# File:Superadventisle2.jpg
# Petronella Barker (actress born 1942)
# British beat
# Phillip De La Perrelle
# Draft:Washington Conservation Guild
# Wikipedia:Miscellany for deletion/User talk:24.5.122.13
# Petronella Barker (disambiguation)
# James Cummings (police commissioner)
# 1929 Kentucky Derby
# File:Newadventisle.jpg
# Template:Attached KML/Utica Avenue
# Phillip Dean
# Category:Isaac Region
# Phillip Dee
# Cyril Docker
# Todd Reed
# Faubourg Lafayette
# Category:Roma Maxima
# U.S. Route 360 Business (Burkeville, Virginia)
# Phillip Deidesheimer
# Phillip Deignan
# Hylaeanthe
# Sondrestrom (settlement)
# Steven G. Blum
# Sinn Féin election results
# Bill Stirling
# Indianthus
# Smith  &  Wesson Model 6906
# Category:Giro dell'Emilia
# Magnolia Plantation (Schriever, Louisiana)
# Souvarit
# Bruvik
# Category:Tour of the Alps
# Lasse Hoikka
# Achryson chacoense
# Category:Miranda Lambert
# Category:Tuberculosis sanatoria in Canada
# Pam Coker
# Achryson foersteri
# Chris Higgins (Australian public servant)
# Da Possessed
# Template:Argentina-hist-book-stub
# Template:Brazil-hist-book-stub
# Template:Mexico-hist-book-stub
# Charles Winning
# Category:Church of England schools in the Diocese of Leeds
# List of Washburne Historic District walking tour houses
# Achryson immaculipenne
# Wikipedia:Articles for deletion/Elemental warriors
# Ischnosiphon
# Achryson immaculipenne var. humeromaculatum
# Achryson unicolor
# Category:Milano–Torino
# Ray Danniels
# Category:Church of England primary schools in the Diocese of Leeds
# Achryson jolyi
# Greniodon
# Achryson concolor
# File:Washington Conservation Guild logo.gif
# Category:Church of England secondary schools in the Diocese of Leeds
# File:Void Terra Firma.jpg
# Category:People from Longridge
# Makers plate
# Category:International ice hockey competitions hosted by Ukraine
# Seagoe parish
# Alaska-class battlecruiser
# Koernickanthe
# Achryson lineolatum
# Wikipedia:WikiProject Spam/LinkReports/blueplanetsociety.org
# Achryson galapagoensis
# Achryson galapagoensis galapagoensis
# Achryson galapagoensis darwini
# Achryson galapagoensis flavescens
# Achryson lineolatum var. andinum
# Achryson scutellatum
# File:Defiance The Prophecy.jpg
# Template:Sci-hist-book-stub
# Malaspina (film)
# File:Money in the Bank 2014 poster.jpg
# File:The Passions of the Mind.jpg
# Wikipedia:Articles for deletion/Phoebe Allen's Hummingbird Webcam
# Template:Science-hist-book-stub
# Category:Colored Conventions
# Let Me Contain That For You
# Morgan The Escapist
# Lavia (genus)
# Achryson lutarium
# Achryson lutariumlutarium var. nigricans
# Nerdy (song)
# New York–New Jersey Line War
# Achryson maculatum
# Makers' plate
# Achryson maculatum var. fusculum
# Burbo Bank Extension offshore wind farm
# Wikipedia:Redirects for discussion/Log/2014 April 27
# Achryson maculipenne
# Chronicon Fontanellense
# Achryson meridionale
# Achryson peracchii
# Contrabbasso ad ancia
# Achryson philippii
# Category:Aldermen of Bussum
# Achryson pictum
# Category:Scheduled association football competitions
# FASTFAT.SYS
# FASTFAT
# Achryson quadrimaculatum
# Wikipedia:Articles for deletion/Log/2014 April 28
# Achryson griseopubescens
# Saint Saviour's, Branston
# Achryson hirsutulum
# Achryson kartaboensis
# Achryson ornatipenne
# Elizabeth Jenns (actress)
# Category:AfC submissions by date/27 April 2014
# Murders of Catherine and Gerard Mahon
# Church of St. Saviour-on-the-Cliff, Shanklin
# Template:TFA title/April 30, 2014
# Sweet XVI
# Megaphrynium
# Bruvik, Hordaland
# Monophrynium
# Gordon Campbell (cricketer)
# Battle of Hamadh
# Washington Center of Foreign Policy Research
# Achryson surinamum
# Achryson circumflexus
# Achryson longicollis
# Achryson pallens
# Achryson simplex
# Achryson surinam
# Achryson surinamensis
# Achryson surinamum var. chontalense
# 2014 South American Rugby Championship  " A "
# Castles in the Air (1939 film)
# Achryson undulatum
# London 2015 Europhilex
# Achryson uniforme
# Category:People educated at Peterborough Regional College
# Wikipedia:WikiProject Spam/LinkReports/petesplanet.co.uk
# Monophyllanthe
# List of Marvel Comics golden age characters
# Castelli in aria
# List of golden age comics publishers
# Cerdaia lunata
# List of Golden Age of Comics publishers
# Cerdaia testacea
# Big ugly satellite dish
# Radio Cure
# Poor Places
# TV receive-only
# Cotyachryson inspergatus
# Modern age of comic books
# Cotyachryson obscurus
# Pot Kettle Black
# Cotyachryson sulcicorne
# Women's African Clubs Championship (volleyball)
# Category:Sea and river deities
# 2014 CONSUR Cup
# Katanga train derailment
# Template:Did you know nominations/Gemma Wilde
# Rock in Rio USA
# Huequenia araucana
# Huequenia livida
# Bebe Sweetbriar
# Template:Kacey Musgraves
# File:Da Possessed movie poster.jpg
# Ragnarr loðbrók
# Xenocompsa flavonitida
# Xenocompsa bifasciatum
# Sanguinones
# Xenocompsa martinsi
# Category:Water goddesses
# Xenocompsa semipolita
# Xenocompsa pallidicornis
# Myrosma
# Phillip Delaporte
# File:Enriquebailandocover.jpg
# Phacelophrynium
# Walter de Gruyter GmbH  &  Co. KG
# Webb's Farm fireworks disaster
# Webb Farm fireworks explosion
# Category:Water gods
# Agallissus lepturoides
# Agallissus clytoides
# Agallissus grata
# Agalissus
# Beyond the Body Farm
# May Mills
# Yakuza Ishin
# Monción Dam
# Ubbe Ragnarsson
# Pleiostachya
# Agallissus melaniodes
# England at the 2014 Commonwealth Games
# Agallissus melaniodes var. quadrimaculatus
# Agallissus melaniodes var. concolor
# Agallissus melaniodes var. trifasciatus
# Faubourg lafayette
# Template:WikiProject Colored Conventions
# USS Oriskany fire
# Portal:Hong Kong/Did you know/5
# 2004 Women's College World Series
# Category:Hydroelectric power stations in Dominican Republic
# Osmopleura chamaeropis
# Osmopleura
# May Mills OBE
# Vaksdal (village)
# Suedo-Norwegian Union
# Korean Standards Association
# Category:Wind deities
# Zagymnus clerinus
# Zagymnus floridanus
# Sanblasia
# Zagymnus
# Conservation scientist (museums)
# Wikipedia:Articles for deletion/Sumter Mall
# Zagymnus rugicollis
# Seeing Anthropology: Cultural Anthropology Through Film
# De Genova (surname)
# Wikipedia:The Missing Manual
# Is Geography Destiny? Lessons from Latin America
# Butler Bulldog
# File:Ready, Steady, Go!.jpg
# Development of the human reproductive system
# Lee Mi-ja (singer)
# Ki Bo-Bae
# Ozone-depleting chemical
# Tang (dynasty)
# Pentapotamia
# Hiroyuki Hayashi (singer)
# Hami–Lop Nur railway
# Naval Supply Depot, Oakland
# Karly Gaitán Morales
# Hami-Lop Nur Railway
# Grigori Petrovski
# 1989 Wales rugby union tour of Canada
# Apex Computer Simulations
# Hideto Takarai
# Teresa mannino
# Sharad Bansode
# Riihinäki
# Category:Maars of Ethiopia
# 1989 Samoa rugby union tour of Europe
# Rasta Ring 0 Debugger
# RR0D
# File:Geneforge III Logo.jpg
# Geneforge III
# Geneforge II
# Nursery Rhyme (game)
# Category:Images of buildings and structures in Italy
# Dāshkasan, Isfahan
# Goat Sim
# File:Starbound Logo.png
# Energy-Safety and Energy-Economy
# Department of Ocean Development
# Sadabhau Khot
# Haluo Railway
# Category:1986–87 in Japanese rugby union
# Syarif
# 1986 Japan rugby union tour of Great Britain
# SS City of Chester
# Al-Irsyad Al-Islamiyah
# Al-Irshād al-Islāmiyyah
# Kiryas Joel, N.Y.
# Module:Main
# Lev Sandakchiev
# Category:1985–86 in Japanese rugby union
# St. Matthew's, Halifax
# 1986 Japan rugby union tour of North America
# Khanpur Khurd
# Bok Koh-il
# Les Presses de l'Université d'Ottawa
# Les Presses de l'Universite d'Ottawa
# Austin Moon
# William J. Keester
# Johannes Frisius
# Ashok Waman Gaikwad
# Trish De la Rosa
# Patricia Maria De la Rosa
# Category:Politicians by occupation
# Hurgronje
# Bernard Neeson
# File:John O Bailey.PNG
# Category:Turkish people of Polish-Jewish descent
# Hollywood sul Tevere
# Wikipedia:WikiProject Spam/LinkReports/taxcutters.com
# Skipperryggen
# File:Geneforge 4 Logo.gif
# File:Geneforge 5 Logo.gif
# R'dam
# Category:Buildings and structures in Hakkari Province
# Category:Ilaiyaraaja soundtracks
# Cortegiani
# Preethsod Thappa
# Extraterrestrial (2014 film)
# Sambas Sultanate
# Mudzi District
# Banjar sultanate
# Banca delle Marche
# Category:Ilaiyaraaja
# Template:Infobox highway system
# William P. Kozlovsky
# Buhweju, Uganda
# Template:Infobox highway system/doc
# Propedesis japonica
# Category:Films directed by Luigi Cozzi
# SR 32 (GA)
# Moscow Geological Exploration Institute
# Meridarchis vitiata
# Cao Xiwen
# Sharp Seven
# Template:British pathe/doc
# Category:Buildings and structures in Giresun Province
# Category:1901 in New Zealand rugby union
# 1901 Waratahs tour of New Zealand
# Category:1901 in New Zealand sport
# Archostola martyr
# Gangs of Haseepur
# Category:1901 in Australian rugby union
# Mikhaïl Nossyrev
# Category:1901 rugby union tours
# File:Game Dev Tycoon logo.png
# Torch (machine learning)
# Time's Up! (game)
# Centovetrine
# Category:Croatian Friars Minor
# Category:Servant Franciscans
# Hydrografbreen
# New Horizons (Charles McPherson album)
# Lumia 530
# Microsoft Lumia 530
# Jatani (Odisha Vidhan Sabha constituency)
# Mexicans in Chicago
# People's Park (Guangzhou)
# E. Mézan de Malartic
# File:Heidelberg West logo.jpg
# Rwanda Mountain Gorilla Rally
# G. Pigeard
# Carposina longipalpalis
# Roosevelt (sailor)
# Andrew Stanley
# EatOye
# History of the Ba'ath Party
# Wikipedia:Image relevance
# History of the Baath Party
# History of the Bath Party
# History of the Ba'th Party
# History of the Arab Socialist Ba'th Party
# History of the Arab Socialist Bath Party
# History of the Arab Socialist Baath Party
# History of the Arab Socialist Ba'ath Party
# St. Doulagh's Church
# Kang Min-jae
# Everybody Knows (McFly song)
# Central Park (Guangzhou)
# Fireworks incident
# Wikipedia:Articles for deletion/BEYOOONLINE.COM
# Autogriphus luteus
# All Fired Up! (Smokie album)
# Guangzhou People's Park
# File:Seagoe Parish Church Logo.png
# Meridarchis regalis
# Rajah Annamalaipuram Ayyappan Koil, Chennai
# The Physics arXiv Blog
# Category:Operas by Antonio Cagnoni
# Wikipedia:WikiAfrica/Stubs/Caledon Museum
# Thalagunda
# Metacosmesis xerostola
# Thomas Leishman
# Category:Soundtracks by composer
# 2014 PBA Governors' Cup Finals
# Secession controversy of 1843
# Sky Movies Disney (UK  &  Ireland)
# A. K. H. Boyd
# Scopalostoma nigromaculella
# J. D. Birla Institute
# Pax Ottomanica
# Area scheme
# Khanpur khurd
# All Fired Up! Live
# Category:Andalusian nationalism
# EXPLORER.EXE
# Mikhail Evgenievich Masson
# Taklong Island National Marine Reserve
# Joshin 7000 series
# File:The Hits Logo.jpg
# 2014 Rugby League Four Nations
# Princely State of Jhansi
# Chiang Mai dwarf gecko
# Jeffrey Vincent Parise
# Category:7th-century paintings
# Islamic extremism in Northern Nigeria
# John Dumelo
# File:Erminie-Theatre Royal 1.jpg
# File:ChoateHallStewartLogo.jpg
# Amit Dhankhar
# Sir Fineen O'Driscoll
# The Green Bird (score)
# Ali Nuhu
# Benefit fraud
# File:Erminie-Theatre Royal 3.jpg
# File:Erminie-Theatre Royal 2.jpg
# Azərbaycan marsı
# Carposina aplegia
# Taklong Island
# Guimaras Oil Spill
# Jupiter Effect
# Provinciaal Hof
# Theodore of Stoudios
# Buffer over-read
# Category:Ambassadors of Lithuania to Germany
# A.E Dimitra Efxeinoupolis
# Kanji Tatsumi
# Merchant foundry
# Template:Database Population Arricau-Bordes
# Buffer overread
# Euthymius of Sardis
# Template:Did you know nominations/Choo Seng Quee
# Sveta Gora
# Don't Play with Tigers
# Category:8th-century Byzantine monks
# Clock Tower Building, Santa Monica
# Kokytos
# File:Don't Play with Tigers.jpg
# Ricchi, ricchissimi... praticamente in mutande
# Runting-stunting syndrome in broilers
# Bryce Peila
# Bishop of Sardis
# Category:Bishops of Sardis
# Shin Hwa-Yong
# Kim Gwang-Seok
# Wikipedia:Articles for deletion/DeVour Magazine
# Wikipedia:Articles for deletion/Chang Welch
# File:Cookingkumarestitlecard.jpg
# Georgi Tenadze
# Shin Young-Jun
# Wikipedia:Articles for deletion/Emmanuel Clottey (boxer)
# Punda (film)
# Lee Gwang-Hoon
# Wikipedia:Articles for deletion/Johnny Colan
# Euthymius of Sardeis
# Euthymios of Sardeis
# Wesley Witherspoon
# Category:Music psychology
# Warahirka
# Kim Chan-Hee
# Kim Dae-Ho
# Category:Epic poems in French
# Huarajirca
# Kim Da-Sol
# Huara Jirca
# Cerro Huara Jirca
# Cerro Huarajirca
# Moon Chang-Jin
# Combretocarpus
# Template:Background
# File:Erminie-1885.jpg
# 971st Airborne Warning and Control Squadron
# Combretocarpus rotundatus
# Yoon Won-Il
# 1st Strategic Support Squadron
# Combretocarpus motleyi
# 1st Troop Carrier Squadron
# 1263d Air Transport Squadron
# 1st Air Transport Unit
# Esophageal spasms
# Bhuma Shobha Nagireddy
# Kim Beom-Jun
# Template:Did you know nominations/Nimdoma Sherpa
# File:Erminie-1886.jpg
# Hwang Kyo-Chung
# Wikipedia:WikiProject Spam/LinkReports/bosson.net
# Ajax-nieuws
# Phil Macquet
# Carpocapsa percicana
# Cloudware
# Bruce Thorburn
# Meridarchis capnarcha
# Meridarchis zymota
# Wikipedia:Sockpuppet investigations/Batka83
# Johannes Belksma
# Cocina
# Covariance mapping
# File:Ajax-nieuws (logo).gif
# Niels Marnegrave
# Panachaiki Volleyball Club
# File:Shobha Nagi Reddy.jpeg
# Moskow Diskow
# ...
# Speedo International Limited
# Agnuside
# Nasir Zaidi
# First generation cephalosporin
# Babe: Pig In The City
# Casa Valentina
# Devudala
# Jonathan White (admiral)
# Jabra
# Caroline Pierce (golfer)
# Premotsava
# Category:Girl's Day albums
# Mykel Benson
# Sing a Song of Wiggles
# Scooby-Doo! Ghastly Goals
# Category:Girl's Day
# File:Hamoun poster.jpg
# Category:Girl's Day members
# Vestgötabreen
# Enopa mediella
# Wikipedia:WikiProject Computing/Article alerts/Archive 3
# Oistophora pterocosmana
# Shakti Prasad
# GNL Zamba
# Gene Timms
# Wikipedia:Articles for deletion/Mukkabla
# Shaktiprasad
# Category:Compositions by Elliot Goldenthal
# Wikipedia:Miscellany for deletion/User:Siconize/Laravel (framework)
# Wikipedia:WikiProject Spam/LinkReports/htmlarea.com
# Alex Toolis
# 2008–09 All-Ireland Senior Club Football Championship
# Category:2014 in Cameroon
# Category:2015 in Australian rugby union
# Category:2015 in New Zealand rugby union
# Category:2015 in South African rugby union
# Copernican cosmology
# Fullerton (surname)
# VOC ship Akerendam
# Category:2014 in Burundi
# File:R5 - Pass Me By.jpg
# Jackie Wharton
# Wikipedia:Sockpuppet investigations/Lockean One/Archive
# Micrelytra fossularum
# Wikipedia:Sockpuppet investigations/Rahulsinghpinaki/Archive
# Wikipedia:Sockpuppet investigations/Andrewbf/Archive
# Wikipedia:Sockpuppet investigations/Ceylobo/Archive
# Wikipedia:Sockpuppet investigations/GagsGagsGags/Archive
# Für
# NTERA2/D1
# Wikipedia:Sockpuppet investigations/Mrgumzet/Archive
# Category:2014 in the Republic of the Congo
# Wikipedia:Sockpuppet investigations/Natas Mon/Archive
# Wikipedia:Sockpuppet investigations/Ali cruse/Archive
# Wikipedia:Sockpuppet investigations/Davidoeoples/Archive
# Resound
# Wikipedia:Sockpuppet investigations/Historicalrevision/Archive
# Category:2014 in Rwanda
# Smith and Williamson
# Spect imaging
# Wikipedia:Sockpuppet investigations/Fredin323/Archive
# Wikipedia:Sockpuppet investigations/Ashwinskn/Archive
# Wikipedia:Sockpuppet investigations/Mkallel/Archive
# Software taggant
# Wikipedia:Sockpuppet investigations/John Hundley/Archive
# Wikipedia:Sockpuppet investigations/Shuppiluliuma/Archive
# Category:2014 in Brunei
# A City Under Siege: Tales of the Iran–Iraq War
# Wikipedia:Sockpuppet investigations/Hashashash/Archive
# Beer tower
# Template:DYKpages sidebar
# Wikipedia:Sockpuppet investigations/Greathassan2011/Archive
# File:DoppelgangerReturns.png
# Category:2014 in Equatorial Guinea
# Wikipedia:Sockpuppet investigations/Gfrsdgerr/Archive
# List of VTB United League season steals leaders
# French ship Soleil-Royal (1670)
# List of number-one singles of 1977 (Spain)
# Thomas Bristow
# Edgar Moline
# Epischnia neurophorella
# School building on Castle Street in Miłosław
# List of power stations in Singapore
# Dritan Smajlaj
# Sculpture in Scotland
# Go Bananas!
# List of VTB United League season blocks leaders
# File:GMTV with Lorraine 2009 Title Card.png
# Mahant Avaidyanath
# Opioid-induced constipation
# Category:People from Svalyava
# Uttar Kazirhat
# Anne Issacs
# Cornish Liberation Army
# Dame Agnes Weston
# Wikipedia:Articles for deletion/RadiumOne
# Template:Did you know nominations/Malin Byström
# File:Layout problem in article - Bliss (image).png
# Eryr Wen
# Meridarchis hylactica
# Meridarchis lembula
# ECC85
# Template:VTB United League
# Levon Panos Dabağyan
# Turbo (Issac Baptiste)
# Hot Poppin' Popcorn
# General Motors LS engine
# Naval tactics in the Age of Sail
# City of Chester (ship)
# St Justinian
# Category:Pupils of Carl Ruggles
# Parbatipur, Bishnupur
# Category:Pupils of Chou Wen-chung
# Category:Pupils of Eduard Steuermann
# St Justinians
# Industry Connections Security Group
# Louder tour
# Category:Pritzker Architecture Prize winners
# Category:Oil shale geology
# Template:VTB United League awards
# List of VTB United League assists leaders
# Rampur (Assembly constituency)
# Meiringen station
# Achimota-class missile boat
# D. J. Stephens (American football)
# St Justinian's
# Template:POTD/2014-05-12
# VTB United League Young Player of the Year
# Holy Trinity Church Templebreedy
# Jet Attack
# St. Maelruain's Church
# Old St. Mary's Church (Clonmel)
# Countries by shale oil reserves
# Church of St. Nicholas Within
# St. Michan's Church
# VTB United League Top Polish Player
# Wikipedia:Articles for deletion/Abdalhadi Alijla (2nd nomination)
# St. Nahi's Church
# Category:Trees of Hong Kong
# Un'amore e una vendetta
# St Finian's Church of Ireland
# NTERA2
# St. Lachtain's Church
# Solidarité basque
# Eli Morse Farm
# Category:Oil shale in Scotland
# Jack of All Trades (film)
# Category:Oil shale in the United Kingdom
# Category:Elections in Plymouth, Devon
# Template:Arkansas-Monticello Boll Weevils football coach navbox
# Marcos dictatorship
# Category:600 mm gauge railways in Spain
# Za Rulyom
# Madeleine Chéruit
# Epitome astronomiae Copernicanae
# Category:Oil shale in France
# %% [markdown]
# Let's see what we've got!

# %%
handler._books[2]
# Out:
# ('DJ Bitman',
#  {'name': 'DJ Bitman',
#   'background': 'non_vocal_instrumentalist',
#   'birth_name': 'José Antonio Bravo',
#   'alias': 'Bitman, Latin Bitman, Bitman and Roban',
#   'origin': 'Arica, Chile',
#   'genre': 'Electronica, hip hop, funk',
#   'occupation': 'DJ, record producer',
#   'years_active': '1999–present',
#   'label': 'Nacional Records, Feria Music',
#   'associated_acts': 'Eric  " Bobo "  Correa, Bitman and Roban, RVSB.',
#   'website': 'Latin Bitman Official website'},
#  ['Arica',
#   'Chile',
#   'Electronica',
#   'hip hop music',
#   'funk',
#   'Disc jockey',
#   'record producer',
#   'Nacional Records',
#   'Feria Music',
#   'Eric_%22Bobo%22_Correa',
#   'electronic music',
#   'DJ',
#   'Sen Dog',
#   'Eric_%22Bobo%22_Correa',
#   'Cypress Hill',
#   'Francisca Valenzuela',
#   'DJ Raff',
#   'Los Tetas',
#   'Anita Tijoux',
#   'Lollapalooza',
#   'Lollapalooza Chile',
#   'EA Sports',
#   'FIFA 07',
#   'FIFA 09',
#   '2010 FIFA World Cup South Africa (video game)',
#   'The Chicas Project',
#   'Arica',
#   'Arica y Parinacota Region',
#   'Chile',
#   'Hip Hop',
#   'Los Tres',
#   'Tiro de Gracia',
#   'Los Tetas',
#   'Double bass',
#   'Marimba',
#   'Guitar',
#   'Piano',
#   'Hammond organ',
#   'jazz',
#   'bossa nova',
#   'funk',
#   'chachachá',
#   'mambo (music)',
#   'Francisca Valenzuela',
#   'Cypress Hill',
#   'Aftershock (2012 film)',
#   'Crystal Fairy  &  the Magical Cactus',
#   'From Prada to Nada (2011)',
#   'Category:1975 births',
#   'Category:Living people',
#   'Category:Chilean musicians',
#   'Category:German techno musicians',
#   'Category:People from Arica',
#   'Category:Nacional Records artists'],
#  {'name': [],
#   'background': [],
#   'birth_name': [],
#   'alias': [],
#   'birth_date': [],
#   'origin': ['Arica', 'Chile'],
#   'genre': ['Electronica', 'hip hop music', 'funk'],
#   'occupation': ['Disc jockey', 'record producer'],
#   'years_active': [],
#   'label': ['Nacional Records', 'Feria Music'],
#   'associated_acts': ['Eric_%22Bobo%22_Correa'],
#   'website': []},
#  '2017-09-02T23:37:51Z',
#  4902)

# %% [markdown]
# For each book, we have the title, the information contained in the `Infobox`, the internal Wikilinks, the external links, the timestamp of the last edit, and the approximate length of the Wikipedia article. Using just this information, we'll be able to build a fairly robust book recommendation system (current project I need the books information for)!

# %% [markdown]
# Let's see how long it would take to search through just one partition. Uncompressed, the size of this partition is 1.5 GB with over 24 million lines.

# %%
# Uncompress the file if not already uncompressed
if not os.path.exists('p15.xml'):
    subprocess.call(['bzcat /Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles15.xml-p7744803p9244803.bz2 >> p15.xml'],
                    shell = True) 
else:
    print('Already uncompressed')
# Out:
# Already uncompressed

# %%
# !wc /Users/christoph.imler/Documents/Wiki_science/p15.xml
# Out:
#  24334570 167158819 1565992571 /Users/christoph.imler/Documents/Wiki_science/p15.xml

# %% [markdown]
# `wc` is a command line utility that gives the number of lines, number of words, and number of bytes in a file.

# %%
import time
from timeit import default_timer as timer

start = timer()
# Object for handling xml
handler = WikiXmlHandler()

# Parsing object
parser = xml.sax.make_parser()
parser.setContentHandler(handler)

# Parse the entire file

print(data_path)
for i, line in enumerate(subprocess.Popen(['bzcat'], 
                         stdin = open(data_path), 
                         stdout = subprocess.PIPE).stdout):
    if (i + 1) % 1000000 == 0:
        print(f'Processed {i + 1} lines so far.')
    try:
        parser.feed(line)
    except StopIteration:
        print('error')
        continue 
        #break
    
end = timer()
books = handler._books

print(f'\nSearched through {handler._article_count} articles.')
print(f'\nFound {len(books)} books in {round(end - start)} seconds.')
# Out:
# /Users/christoph.imler/.keras/datasets/enwiki-20190601-pages-articles-multistream26.xml-p42567204p42663461.bz2
# Processed 1000000 lines so far.
#
# Searched through 28732 articles.
#
# Found 90 books in 103 seconds.

# %% [markdown]
# If we multiply the time to process one partition, about 1000 seconds, by the number of partitions, 55, we get 55,000 seconds to process all the files one at a time. This amounts to 15 hours! We'll see if we can do better using multiprocessing.

# %%
books = handler._books
len(books)
# Out:
# 90

# %% [markdown]
# ### Writing to File
#
# The best way to save the information is as `ndjson`. We can save and then load back in the books using the `json` library.

# %% [markdown]
# # Running Operations in Parallel
#
# Instead of parsing through the files one at a time, we want to process several of them at once. We can do this using parallelization, either through multithreading or multiprocessing.
#
#
# ## Multithreading and Multiprocessing
#
# Multithreading and multiprocessing are ways to carry out many tasks on a computer - or multiple computers - simulataneously. We have a number of files on disk, each of which needs to be parsed in the same way. A naive approach would be to parse one file at a time, but that is not taking full advantage of our resources. Instead, we can use either multithreading or multiprocessing to parse many files at the same time, greatly speeding up the overall process.
#
# Learning multithreading / multiprocessing is essential for making your data science workflows more efficient. I'd recommend [this article](https://medium.com/@bfortuner/python-multithreading-vs-multiprocessing-73072ce5600b) to get started with the concepts.
#
# Generally multithreading works better (is faster) for input / output bound tasks, such as reading in files or making requests. Multiprocessing works better (is faster) for cpu bound tasks. Due to the [global interpreter lock](https://realpython.com/python-gil/), only one thread can run at a time in Python for cpu intensive tasks (such as doing mathematical operations or machine learning) even on a multithreaded / multicore system. Running multiple processes does not have this issue because processes do not share memory. In some cases, you cannot use multiple processes because the tasks need to share memory. However, in our case, each file can be processed independently of the others. For that reason, we can use either multithreading or mulitprocessing.
#
# I've found the best method for determining the optimal method and parameters is to try out a number of different options. The code for testing multithreding and mutltiprocessing appears at the end of the notebook. When I ran the tests, I found multiprocessing was much faster indicating this process is probably CPU bound (limited).
#
# __The final process of searching for all books on Wikipedia is run in parallel using 16 processes__. This was the fastest method in my benchmarking. Each process is run on a different core because the machine I used had 16 cores. The best options will depend on your set-up so I'd recommend testing a few different parameters.

# %% [markdown]
# ### Setting Up Parallel Code
#
# To run an operation in parallel, we need a `service` and `tasks`. A `service` can be a function that we need to run many times and the `tasks` are a list of objects that we want to apply the function to. For our purposes, the service is the `find_books` function that parses a complete compressed xml file for the books and the tasks are all of the compressed xml files. Each task will be sent to the service, but instead of one at a time, we can run 16 at a time (or however many cores your machine has).

# %%
import gc
import json

def find_artist(data_path, limit = None, save = True):
    """Find all the book articles from a compressed wikipedia XML dump.
       `limit` is an optional argument to only return a set number of books.
        If save, books are saved to partition directory based on file name"""

    # Object for handling xml
    handler = WikiXmlHandler()

    # Parsing object
    parser = xml.sax.make_parser()
    parser.setContentHandler(handler)

    # Iterate through compressed file
    for i, line in enumerate(subprocess.Popen(['bzcat'], 
                             stdin = open(data_path), 
                             stdout = subprocess.PIPE).stdout):
        try:
            parser.feed(line)
        except StopIteration:
            break
            
        # Optional limit
        if limit is not None and len(handler._books) >= limit:
            #break
            return handler._books
    
    if save:
        partition_dir = 'data/'
        # Create file name based on partition name
        p_str = data_path.split('-')[-1].split('.')[-2]
        out_dir = partition_dir + f'{p_str}.ndjson'

        # Open the file
        with open(out_dir, 'w') as fout:
            # Write as json
            for book in handler._books:
                fout.write(json.dumps(book) + '\n')
        
        print(f'{len(os.listdir(partition_dir))} files processed.', end = '\r')

    # Memory management
    del handler
    del parser
    gc.collect()
    return None

# %% [markdown]
# Next we need a list of services. This is simply all the partitioned data files we want to send to the function.

# %%
find_artist(files_list[15],3)
# Out:
# Kim Hyeon-Woo
# Lee Se-Yeol
# Marko Virtanen
# João de Oliveira
# File:David and Goliath -1700s.jpg
# 2014–15 Northern Illinois Huskies men's basketball team
# Category:Scottish people of Russian-Jewish descent
# Kim Jin-Hyeok
# Sherri Jean Tucker
# Yellow fat-tail scorpion
# Category:Sculptures in New York (state)
# Kim Jin-Cheol
# File:Pressure (play).jpg
# Gavin Turek
# Hypoxis juncea
# Sishen–Saldanha Orex line
# Mathews Mr Easy
# 2014–15 Toledo Rockets men's basketball team
# Kim Young-Nam
# Falcon 9 flight 11
# ADT Event Center
# Kim Ji-Hun (wrestler)
# Blitz kids
# Little River Turnpike Bridge
# Category:Mathews aircraft
# Yellow fattail scorpion
# Anssi Laine
# Template:Taxonomy/Corallus
# Claude Koutob
# Nikolay Valeryevich Markov
# Kim Ik-Hee
# Falcon 9 flight 12
# Category:Sculptures in Massachusetts
# Ryu Han-Su
# Tampa Shores, Florida
# Tampa Shores, FL
# Little Shasta Church
# Category:Filton
# Mr Easy
# Mr. Easy
# Mathews Mr. Easy
# Falcon 9 flight 13
# Donyi-Poloism
# Category:Films scored by Ilaiyaraaja
# Take Me to Church
# Donyipoloism
# Falcon 9 flight 14
# Category:Airdrieonians F.C. (1878) wartime guest players
# Category:Scottish people of Polish-Jewish descent
# Falcon 9 flight 15
# Sedism
# Son Gab-Do
# Tanism
# Falcon 9 flight 16
# Rangfraism
# List of Tulane Green Wave football All-Americans
# Intayaism
# Category:Sculptures in Washington, D.C.
# SR 179 (GA)
# Roxanne wars
# Ali Elmusrati
# Portal:Hong Kong/Did you know/2
# 2d Interceptor Command
# Chang Chang-Sun
# Kim Woo-Yong
# The Gospel Channel
# 2014 Commonwealth Games Marathon Course
# L. Royal Christensen
# Fungal sex
# Category:Jewish Scottish history
# Akka (film)
# Fringed yellow star-grass
# Fringed yellow stargrass
# Fringed yellow star grass
# Fringed yellow star-grasses
# Fringed yellow star grasses
# Rushy hypoxis
# Category:Articles containing potentially dated statements from May 2014
# Bernard Salomon Lewinsky
# H. juncea
# Heidi Hazell (IRA murder victim)
# Athletics at the 1999 All-Africa Games – Women's heptathlon
# Analia Saban
# Tenmile, Coos County, Oregon
# Aizik Homiler
# Boxers Tour
# Donax canniformis
# Template:Attached KML/Flatlands Avenue
# Category:Chilean people of Latvian-Jewish descent
# Category:Hong Kong portal did you know
# Wikipedia:WikiProject Spam/LinkReports/thedreamtravelgroup.co.uk
# Category:Chilean people of Latvian descent
# Wikipedia:WikiProject Spam/LinkReports/modwedding.com
# Little Saigon, Orange County
# Category:Latvian emigrants to Chile
# Colt M1847 Walker
# Wikipedia:WikiProject Spam/LinkReports/cokincokine.com
# Goblins in the Castle
# 2014 Indian general election in Andhra Pradesh
# Template:Attached KML/Manhattan Avenue (Brooklyn)
# Colt M1836 Patterson
# Wikipedia:Miscellany for deletion/User:Synsepalum2013/sandbox/Voice to skull
# J. Ellis Rodley
# Naples in Green and Blue
# Category:People of Mexican-Jewish descent
# ActiveState Komodo
# Napoli verde-blu
# Andrea Ekonomi
# John Ellis Rodley
# 24th Army Tank Brigade
# Template:Granada CF managers
# Chris McGurk
# Template:Attached KML/Vanderbilt Avenue
# Halopegia
# Belmont Filmhouse, Aberdeen
# Amman Koil Kizhakale
# The Belmont Filmhouse, Aberdeen
# Paul Gleeson (magician)
# Lisa Lapinski
# Sotos
# CHRIS MCGURK
# Louis L. Martz
# La Madrastra (2005 TV series)
# Amman Koil Thiruvizha
# La madrastra
# British 87th Armoured Brigade (Dummy Tanks)
# Robert Cyril Morton Jenkins
# British 74th Armoured Brigade (Dummy Tanks)
# Aristocrat fashion
# Frank Richardson (policeman)
# Template:Staten Island Streets
# Shen Zhong
# Fredrik Møller
# Template:Brooklyn Streets
# New Gothic Art
# Wikipedia:Categories for discussion/Discussions awaiting closure
# Harry Heath
# Argile Smith
# Alexei Vasilevsky (figure skater)
# Alexei Vasilevsky
# Wikipedia:Templates for discussion/Log/2014 April 24
# Blair Athol, Queensland
# Wikipedia:Files for deletion/2014 April 24
# Wikipedia:Deletion review/Log/2014 April 24
# Wikipedia:Possibly unfree files/2014 April 24
# Marondera District
# Armando Fizzarotti
# Dennis O'Brien (policeman)
# Edward Grey (policeman)
# Category:Films directed by Armando Fizzarotti
# Nightfever
# Richard Fallon (policeman)
# Ed Long (cricketer)
# File:NESIsland.gif
# Lu Deming
# Kalevala (corvette)
# John Coughlin (policeman)
# Maker's plate
# Members of the Victorian Legislative Assembly, 1894–1897
# James Farrell (policeman)
# John Cullen (policeman)
# Haumania
# Anal Kaatru
# Petronella Barker (actress born 1965)
# John C. Ferguson (Sinologist)
# UFO researcher
# File:Superadventisle2.jpg
# Petronella Barker (actress born 1942)
# British beat
# Phillip De La Perrelle
# Draft:Washington Conservation Guild
# Wikipedia:Miscellany for deletion/User talk:24.5.122.13
# Petronella Barker (disambiguation)
# James Cummings (police commissioner)
# 1929 Kentucky Derby
# File:Newadventisle.jpg
# Template:Attached KML/Utica Avenue
# Phillip Dean
# Category:Isaac Region
# Phillip Dee
# Cyril Docker
# Todd Reed
# Faubourg Lafayette
# Category:Roma Maxima
# U.S. Route 360 Business (Burkeville, Virginia)
# Phillip Deidesheimer
# Phillip Deignan
# Hylaeanthe
# Sondrestrom (settlement)
# Steven G. Blum
# Sinn Féin election results
# Bill Stirling
# Indianthus
# Smith  &  Wesson Model 6906
# Category:Giro dell'Emilia
# Magnolia Plantation (Schriever, Louisiana)
# Souvarit
# Bruvik
# Category:Tour of the Alps
# Lasse Hoikka
# Achryson chacoense
# Category:Miranda Lambert
# Category:Tuberculosis sanatoria in Canada
# Pam Coker
# Achryson foersteri
# Chris Higgins (Australian public servant)
# Da Possessed
# Template:Argentina-hist-book-stub
# Template:Brazil-hist-book-stub
# Template:Mexico-hist-book-stub
# Charles Winning
# Category:Church of England schools in the Diocese of Leeds
# List of Washburne Historic District walking tour houses
# Achryson immaculipenne
# Wikipedia:Articles for deletion/Elemental warriors
# Ischnosiphon
# Achryson immaculipenne var. humeromaculatum
# Achryson unicolor
# Category:Milano–Torino
# Ray Danniels
# Category:Church of England primary schools in the Diocese of Leeds
# Achryson jolyi
# Greniodon
# Achryson concolor
# File:Washington Conservation Guild logo.gif
# Category:Church of England secondary schools in the Diocese of Leeds
# File:Void Terra Firma.jpg
# Category:People from Longridge
# Makers plate
# Category:International ice hockey competitions hosted by Ukraine
# Seagoe parish
# Alaska-class battlecruiser
# Koernickanthe
# Achryson lineolatum
# Wikipedia:WikiProject Spam/LinkReports/blueplanetsociety.org
# Achryson galapagoensis
# Achryson galapagoensis galapagoensis
# Achryson galapagoensis darwini
# Achryson galapagoensis flavescens
# Achryson lineolatum var. andinum
# Achryson scutellatum
# File:Defiance The Prophecy.jpg
# Template:Sci-hist-book-stub
# Malaspina (film)
# File:Money in the Bank 2014 poster.jpg
# File:The Passions of the Mind.jpg
# Wikipedia:Articles for deletion/Phoebe Allen's Hummingbird Webcam
# Template:Science-hist-book-stub
# Category:Colored Conventions
# Let Me Contain That For You
# Morgan The Escapist
# Lavia (genus)
# Achryson lutarium
# Achryson lutariumlutarium var. nigricans
# Nerdy (song)
# New York–New Jersey Line War
# Achryson maculatum
# Makers' plate
# Achryson maculatum var. fusculum
# Burbo Bank Extension offshore wind farm
# Wikipedia:Redirects for discussion/Log/2014 April 27
# Achryson maculipenne
# Chronicon Fontanellense
# Achryson meridionale
# Achryson peracchii
# Contrabbasso ad ancia
# Achryson philippii
# Category:Aldermen of Bussum
# Achryson pictum
# Category:Scheduled association football competitions
# FASTFAT.SYS
# FASTFAT
# Achryson quadrimaculatum
# Wikipedia:Articles for deletion/Log/2014 April 28
# Achryson griseopubescens
# Saint Saviour's, Branston
# Achryson hirsutulum
# Achryson kartaboensis
# Achryson ornatipenne
# Elizabeth Jenns (actress)
# Category:AfC submissions by date/27 April 2014
# Murders of Catherine and Gerard Mahon
# Church of St. Saviour-on-the-Cliff, Shanklin
# Template:TFA title/April 30, 2014
# Sweet XVI
# Megaphrynium
# Bruvik, Hordaland
# Monophrynium
# Gordon Campbell (cricketer)
# Battle of Hamadh
# Washington Center of Foreign Policy Research
# Achryson surinamum
# Achryson circumflexus
# Achryson longicollis
# Achryson pallens
# Achryson simplex
# Achryson surinam
# Achryson surinamensis
# Achryson surinamum var. chontalense
# 2014 South American Rugby Championship  " A "
# Castles in the Air (1939 film)
# Achryson undulatum
# London 2015 Europhilex
# Achryson uniforme
# Category:People educated at Peterborough Regional College
# Wikipedia:WikiProject Spam/LinkReports/petesplanet.co.uk
# Monophyllanthe
# List of Marvel Comics golden age characters
# Castelli in aria
# List of golden age comics publishers
# Cerdaia lunata
# List of Golden Age of Comics publishers
# Cerdaia testacea
# Big ugly satellite dish
# Radio Cure
# Poor Places
# TV receive-only
# Cotyachryson inspergatus
# Modern age of comic books
# Cotyachryson obscurus
# Pot Kettle Black
# Cotyachryson sulcicorne
# Women's African Clubs Championship (volleyball)
# Category:Sea and river deities
# 2014 CONSUR Cup
# Katanga train derailment
# Template:Did you know nominations/Gemma Wilde
# Rock in Rio USA
# Huequenia araucana
# Huequenia livida
# Bebe Sweetbriar
# Template:Kacey Musgraves
# File:Da Possessed movie poster.jpg
# Ragnarr loðbrók
# Xenocompsa flavonitida
# Xenocompsa bifasciatum
# Sanguinones
# Xenocompsa martinsi
# Category:Water goddesses
# Xenocompsa semipolita
# Xenocompsa pallidicornis
# Myrosma
# Phillip Delaporte
# File:Enriquebailandocover.jpg
# Phacelophrynium
# Walter de Gruyter GmbH  &  Co. KG
# Webb's Farm fireworks disaster
# Webb Farm fireworks explosion
# Category:Water gods
# Agallissus lepturoides
# Agallissus clytoides
# Agallissus grata
# Agalissus
# Beyond the Body Farm
# May Mills
# Yakuza Ishin
# Monción Dam
# Ubbe Ragnarsson
# Pleiostachya
# Agallissus melaniodes
# England at the 2014 Commonwealth Games
# Agallissus melaniodes var. quadrimaculatus
# Agallissus melaniodes var. concolor
# Agallissus melaniodes var. trifasciatus
# Faubourg lafayette
# Template:WikiProject Colored Conventions
# USS Oriskany fire
# Portal:Hong Kong/Did you know/5
# 2004 Women's College World Series
# Category:Hydroelectric power stations in Dominican Republic
# Osmopleura chamaeropis
# Osmopleura
# May Mills OBE
# Vaksdal (village)
# Suedo-Norwegian Union
# Korean Standards Association
# Category:Wind deities
# Zagymnus clerinus
# Zagymnus floridanus
# Sanblasia
# Zagymnus
# Conservation scientist (museums)
# Wikipedia:Articles for deletion/Sumter Mall
# Zagymnus rugicollis
# Category:Rain
# Neoclassical (New Age)
# Marois government
# Zagymnus variatus
# Category:WikiProject Colored Conventions articles
# The Black Corsair (1937 film)
# File:Axis axis (Nagarhole, 2010).jpg
# Category:E. W. Scripps Company people
# Saranthe
# Microclytus compressicollis
# Wikipedia:Articles for deletion/The JLP (cocktail)
# Microclytus gibbulus
# Gocomics
# Microclytus insinuans
# Microclytus niger
# Microclytus compressicornis
# Microclytus frosti
# Wikipedia:Sockpuppet investigations/Gfrsdgerr
# Feakle GAA
# Category:Rain deities
# File:Lucas Sullivant.jpg
# Microclytus gazellula
# Francisco de Arango y Parreño
# Stachyphrynium
# Sindone Chapel
# Carl Shroeder
# Unguarded Women
# Donetsk crisis
# Robert R. Bishop
# RR0D
# File:Geneforge III Logo.jpg
# Geneforge III
# Geneforge II
# Nursery Rhyme (game)
# Category:Images of buildings and structures in Italy
# Dāshkasan, Isfahan
# Goat Sim
# File:Starbound Logo.png
# Energy-Safety and Energy-Economy
# Department of Ocean Development
# Sadabhau Khot
# Haluo Railway
# Category:1986–87 in Japanese rugby union
# Syarif
# 1986 Japan rugby union tour of Great Britain
# SS City of Chester
# Al-Irsyad Al-Islamiyah
# Al-Irshād al-Islāmiyyah
# Kiryas Joel, N.Y.
# Module:Main
# Lev Sandakchiev
# Category:1985–86 in Japanese rugby union
# St. Matthew's, Halifax
# 1986 Japan rugby union tour of North America
# Khanpur Khurd
# Bok Koh-il
# Les Presses de l'Université d'Ottawa
# Les Presses de l'Universite d'Ottawa
# Austin Moon
# William J. Keester
# Johannes Frisius
# Ashok Waman Gaikwad
# Trish De la Rosa
# Patricia Maria De la Rosa
# Category:Politicians by occupation
# Hurgronje
# Bernard Neeson
# File:John O Bailey.PNG
# Category:Turkish people of Polish-Jewish descent
# Hollywood sul Tevere
# Wikipedia:WikiProject Spam/LinkReports/taxcutters.com
# Skipperryggen
# File:Geneforge 4 Logo.gif
# File:Geneforge 5 Logo.gif
# R'dam
# Category:Buildings and structures in Hakkari Province
# Category:Ilaiyaraaja soundtracks
# Cortegiani
# Preethsod Thappa
# Extraterrestrial (2014 film)
# Sambas Sultanate
# Mudzi District
# Banjar sultanate
# Banca delle Marche
# Category:Ilaiyaraaja
# Template:Infobox highway system
# William P. Kozlovsky
# Buhweju, Uganda
# Template:Infobox highway system/doc
# Propedesis japonica
# Category:Films directed by Luigi Cozzi
# SR 32 (GA)
# Moscow Geological Exploration Institute
# Meridarchis vitiata
# Cao Xiwen
# Sharp Seven
# Template:British pathe/doc
# Category:Buildings and structures in Giresun Province
# Category:1901 in New Zealand rugby union
# 1901 Waratahs tour of New Zealand
# Category:1901 in New Zealand sport
# Archostola martyr
# Gangs of Haseepur
# Category:1901 in Australian rugby union
# Mikhaïl Nossyrev
# Category:1901 rugby union tours
# File:Game Dev Tycoon logo.png
# Torch (machine learning)
# Time's Up! (game)
# Centovetrine
# Category:Croatian Friars Minor
# Category:Servant Franciscans
# Hydrografbreen
# New Horizons (Charles McPherson album)
# Lumia 530
# Microsoft Lumia 530
# George Washington Sprott
# Norman Macleod the younger
# Roberto Mendes da Silva
# File:New Horizons (Charles McPherson album).jpg
# Hymn of Love
# Ave!Comics
# Păltiniş River (Bâsca)
# Păltiniş River (Cibin)
# Păltiniş River (Bistricioara)
# Category:Post–Civil Rights Era African-American history
# Template:Joseph Kane
# Bridge It
# Toowong, Queensland
# Bondia xylinarcha
# Template:Database Population Arreux
# Lazy gob
# File:Peter Paul Rubens - The Fall of Phaeton (National Gallery of Art).jpg
# Păltiniș River
# Honda Indy V8
# Păltinişul Mare River
# Păltinişul Mic River
# List of number-one singles of 1974 (Spain)
# Baseballin SM-sarja
# Template:Did you know nominations/Titus Andronicus (character)
# The Big Day (1959 film)
# Jean d'Estournelles de Constant
# All Fired Up! (Smokie album)
# Guangzhou People's Park
# File:Seagoe Parish Church Logo.png
# Meridarchis regalis
# Rajah Annamalaipuram Ayyappan Koil, Chennai
# The Physics arXiv Blog
# Category:Operas by Antonio Cagnoni
# Wikipedia:WikiAfrica/Stubs/Caledon Museum
# Thalagunda
# Metacosmesis xerostola
# Thomas Leishman
# Category:Soundtracks by composer
# 2014 PBA Governors' Cup Finals
# Secession controversy of 1843
# Sky Movies Disney (UK  &  Ireland)
# A. K. H. Boyd
# Scopalostoma nigromaculella
# J. D. Birla Institute
# Pax Ottomanica
# Area scheme
# Khanpur khurd
# All Fired Up! Live
# Category:Andalusian nationalism
# EXPLORER.EXE
# Mikhail Evgenievich Masson
# Taklong Island National Marine Reserve
# Joshin 7000 series
# File:The Hits Logo.jpg
# 2014 Rugby League Four Nations
# Princely State of Jhansi
# Chiang Mai dwarf gecko
# Jeffrey Vincent Parise
# Category:7th-century paintings
# Islamic extremism in Northern Nigeria
# John Dumelo
# File:Erminie-Theatre Royal 1.jpg
# File:ChoateHallStewartLogo.jpg
# Amit Dhankhar
# Sir Fineen O'Driscoll
# The Green Bird (score)
# Ali Nuhu
# Benefit fraud
# File:Erminie-Theatre Royal 3.jpg
# File:Erminie-Theatre Royal 2.jpg
# Azərbaycan marsı
# Carposina aplegia
# Taklong Island
# Guimaras Oil Spill
# Jupiter Effect
# Provinciaal Hof
# Theodore of Stoudios
# Buffer over-read
# Category:Ambassadors of Lithuania to Germany
# A.E Dimitra Efxeinoupolis
# Kanji Tatsumi
# Merchant foundry
# Template:Database Population Arricau-Bordes
# Buffer overread
# Euthymius of Sardis
# Template:Did you know nominations/Choo Seng Quee
# Sveta Gora
# Don't Play with Tigers
# Category:8th-century Byzantine monks
# Clock Tower Building, Santa Monica
# Kokytos
# File:Don't Play with Tigers.jpg
# Ricchi, ricchissimi... praticamente in mutande
# Runting-stunting syndrome in broilers
# Bryce Peila
# Bishop of Sardis
# Category:Bishops of Sardis
# Shin Hwa-Yong
# Kim Gwang-Seok
# Wikipedia:Articles for deletion/DeVour Magazine
# Wikipedia:Articles for deletion/Chang Welch
# File:Cookingkumarestitlecard.jpg
# Georgi Tenadze
# Shin Young-Jun
# Wikipedia:Articles for deletion/Emmanuel Clottey (boxer)
# Punda (film)
# Lee Gwang-Hoon
# Wikipedia:Articles for deletion/Johnny Colan
# Euthymius of Sardeis
# Euthymios of Sardeis
# Wesley Witherspoon
# Category:Music psychology
# Warahirka
# Kim Chan-Hee
# Kim Dae-Ho
# Category:Epic poems in French
# Huarajirca
# Kim Da-Sol
# Huara Jirca
# Cerro Huara Jirca
# Cerro Huarajirca
# Moon Chang-Jin
# Combretocarpus
# Template:Background
# File:Erminie-1885.jpg
# 971st Airborne Warning and Control Squadron
# Combretocarpus rotundatus
# Yoon Won-Il
# 1st Strategic Support Squadron
# Combretocarpus motleyi
# 1st Troop Carrier Squadron
# 1263d Air Transport Squadron
# 1st Air Transport Unit
# Esophageal spasms
# Bhuma Shobha Nagireddy
# Kim Beom-Jun
# Template:Did you know nominations/Nimdoma Sherpa
# File:Erminie-1886.jpg
# Hwang Kyo-Chung
# Wikipedia:WikiProject Spam/LinkReports/bosson.net
# Ajax-nieuws
# Phil Macquet
# Carpocapsa percicana
# Cloudware
# Bruce Thorburn
# Meridarchis capnarcha
# Meridarchis zymota
# Wikipedia:Sockpuppet investigations/Batka83
# Johannes Belksma
# Cocina
# Covariance mapping
# File:Ajax-nieuws (logo).gif
# Niels Marnegrave
# Panachaiki Volleyball Club
# File:Shobha Nagi Reddy.jpeg
# Moskow Diskow
# ...
# Category:Oil shale in the United Kingdom
# Category:Elections in Plymouth, Devon
# Template:Arkansas-Monticello Boll Weevils football coach navbox
# Marcos dictatorship
# Category:600 mm gauge railways in Spain
# Za Rulyom
# Madeleine Chéruit
# Epitome astronomiae Copernicanae
# Category:Oil shale in France
# New American Fiction Prize
# PHBA
# File:NTERA-2 differentiation.png
# Category:Russian automobile magazines
# Land transportation in the Philippines
# Nong Shim Ltd.
# Viktor Herzfeld
# Baltic Oil Shale Basin
# Category:2014 in Niue
# Eli Morse Sawmill Foundations
# Epitome of Copernican Astronomy
# Agency, Mississippi
# Template:Did you know nominations/Liberec Region
# Victorian state women's cricket team
# Conservative party HQ
# Reichenbachfall railway
# Co-operative Bank Group
# Marco Antonio Solís y Los Bukis
# Mountain View Farm (Dublin, New Hampshire)
# Antoine René Charles Mathurin, comte de Laforest
# Mojo In The Morning
# Wikipedia:Articles for deletion/Mackenzie Ziegler
# Wikipedia:Peer review/Development of Grand Theft Auto V/archive1
# Fidel Maruhi
# Bossard Holding AG
# File:Cover of  " Za Rulem "  magazine.jpg
# Achiasmy
# Wikipedia:Articles for deletion/A Split in Duality
# Devolving power
# Haldane-Huxley rule
# Heterochiasmy
# Co-op movement
# Georges Warenhorst
# Natural Theology or Evidences of the Existence and Attributes of the Deity
# Richard O'Rawe
# Isog
# Dekel Bor
# India–Yemen relations
# Marcel Moisand
# Ao Oni (film)
# Yamato Hotsuin
# Lee Albon
# Draft:Animalia (disambiguation)
# Category:600 mm gauge railways in Chile
# Lecointre
# List of TNA co-operative pay-per-view events
# Putagán—Colbún railway
# Category:Serbian expatriates in Oman
# Nadeem-Shravan
# Norman F. Dixon
# Sergei Einstein
# 劉向
# Asiacarposina cornusvora
# 劉子政
# Tripsitypa cardinata
# Single line diagram
# 松井稼頭央
# CGIU
# Ouch! (song)
# File:CausticLove.jpg
# Template:Did you know nominations/Carling Campus
# Carposina maritima
# Between The Dim  &  The Dark
# Tepe, Gülnar
# Cameleon (programming language)
# Draft:David Ehrenfeld
# Prospect Hill Historic District (New Haven)
# Oww
# Chebakia
# Joep Franssens
# United States Institute of Peace Kabul Office
# Il ritorno di Don Camillo
# Le Retour de don Camillo
# File:NK Smartno.png
# Template:Format link/doc
# File:Republic Pictures.jpg
# Template:1962 Big Ten Conference baseball standings
# Category:1962 NCAA University Division baseball standings templates
# Sid Gottlieb
# Category:1962 Big Ten Conference baseball season
# The Friends of Natasha
# Wikipedia:WikiProject Spam/LinkReports/bugs3.com
# 平賀源内
# Five offences
# OWW (disambiguation)
# Isa Pola
# File:Alfred Dunhill in 1893.jpeg
# Wikipedia:WikiProject Spam/LinkReports/thisismaps.com
# Staffordshire Oatcake
# Quasi-crystals
# Category:Pupils of Virgil Thomson
# East Mashonaland
# Category:Pupils of K. P. H. Notoprojo
# Book:Sherpa mountaineers
# Category:Orthopedics stubs
# Silent Library (MTV series)
# List of RORO vessel accidents
# Template:Yorkshire First/meta/color
# Template:Yorkshire First/meta/shortname
# File:Magazine Cover Autoreview.png
# Pak No-ja
# Keep It To Yourself (song)
# Template:Birmingham County Football Association Cup Competitions
# Wallack's Theatres
# Category:Ster Zeeuwsche Eilanden
# Portage (Anchorage)
# Girl of the Golden West (1942 film)
# Template:1948 Eastern Intercollegiate Baseball League baseball standings
# Category:1948 Eastern Intercollegiate Baseball League baseball season
# Template:Latest stable software release/ActiveState Komodo
# Category:Pupils of Alban Berg
# United Nations General Assembly Resolution 31/136
# Genetically modified food labeling
# Wikipedia:Articles for deletion/CVSL
# Ejil
# Wikipedia:Articles for deletion/Thani Oruvan
# Ministerial Church
# Kim King (politician)
# Wikipedia:BOLD-revert-discuss cycle
# Category:Films directed by Carl Koch
# Gergely Bobal
# NEIRRS
# Category:Amstel Curaçao Race
# The New Girls
# Guitar Zero
# Ornithological Dictionary
# El Nuevo Gasómetro
# Ethnicity in Honduras
# Category:Thüringen Rundfahrt der Frauen
# Category:20th-century Bulgarian actresses
# File:MeanwhileBackatMamas.jpg
# Fort-Coulonge, Quebec
# Edwin Hansen
# Maksim Igorevich Pavlov
# Almost holomorphic modular form
# 2014 World Karate Championships
# Maksim Vladimirovich Pavlov
# Category:Railway lines opened in 1946
# Wikipedia:Sockpuppet investigations/Kliff93
# Category:2014 in karate
# Quasimodular form
# Eusko Alkartasuna
# File:Guitar Zero book cover.png
# Basque Solidarity
# Quasi modular form
# Havre-Saint-Pierre, Quebec
# Quasi-modular form
# Robert Longacre
# 2014 Grand Prix de Dottignies
# William Robinson (theologian)
# Ivujivik, Quebec
# Category:Italian Western (genre) films
# Liberty Park
# Harry Smith (footballer, born 1908)
# David Divine
# Kangiqsualujjuaq, Quebec
# EDSA (company)
# John Cairns (politician)
# Ilya Volkov (singer)
# Wikipedia:Articles for deletion/King Edward Avenue (Vancouver)
# Billy Mae Richards
# 1979-80 Seattle SuperSonics season
# Abõ
# William D. Chapple
# 2014 Winston-Salem Cycling Classic
# Slavic calendar
# Chilika (Odisha Vidhan Sabha constituency)
# Elton John albums discography
# Fitz Steele
# Modellist-ID
# List of indoor arenas in Belgium
# Cardinal Messias
# Sir John Carr
# Kangirsuk, Quebec
# Abuna Messias
# Kuujjuarapik, Quebec
# Bambang Sumantri
# Anti-citrullinated protein antibody
# Product-market fit
# Masson-Angers, Quebec
# Product/Market Fit
# Woldemichael Solomon
# Wikipedia:WikiProject Oregon/Photography/Pride PDX
# Kim Byung-Suk
# Nemaska, Quebec
# Ward Edmonds
# Roman Nykytyuk
# R. Ward Edmonds
# Nemiscau, Quebec
# Armstrong Labs
# Slice and Dice: The Slasher Film Forever
# The Boxer and Death
# Venernbreen
# Gian Paolo Rosmino
# Victorian Village - Columbus, Ohio
# Gianpaolo Rosmino
# Beinn a'Chrulaiste
# Rochon
# Britons (Celtic tribe)
# 1994 CCHA Men's Ice Hockey Tournament
# Andrés Bucci
# Category:Multi-sport events in Germany
# The Long Hair of Death
# Shaun Byrne (footballer, born 1993)
# Shaun Byrne (Scottish footballer)
# Shaun Byrne
# 2014–15 Louisville Cardinals men's basketball team
# Arts, Entertainment  &  Media Management
# Category:Multi-sport events in Greece
# Will Coursey
# Saint-Jérôme Panthers
# Wikipedia:WikiProject Spam/LinkReports/bunute.ro
# Dig Up The Dead
# 2014 Norwegian Premier League
# 2014 Norwegian Second Division
# Baader-Meinhof phenomenon
# DJ Bitman
# [('Gavin Turek',
#   {'embed': 'yes', 'background': 'solo_singer  < !-- mandatory field-- >'},
#   ['Los Angeles, California',
#    'United States',
#    'Disco',
#    'Dance music',
#    'Los Angeles, California',
#    'The Troubadour, London',
#    'Hollywood Bowl',
#    'Palladium (New York City)',
#    'El Rey Theatre',
#    'Donna Summer',
#    'extended play',
#    'Tokimonsta',
#    'Myspace',
#    'Mayer Hawthorne',
#    'Billboard (magazine)',
#    'Billboard (magazine)',
#    'Spin Magazine',
#    'Spin (magazine)',
#    'LA Weekly',
#    'LA Weekly',
#    'Category:Living people',
#    'Category:American female singers',
#    'Category:American actresses',
#    'Category:Year of birth missing (living people)'],
#   {'embed': [],
#    'background': [],
#    'genre': ['Disco', 'Dance music'],
#    'website': []},
#   '2018-07-25T00:31:21Z',
#   1575),
#  ('GNL Zamba',
#   {'name': 'GNL Zamba',
#    'image': 'GNL Zamba 01.jpg',
#    'landscape': '< !-- yes, if wide image, otherwise leave blank -- >',
#    'background': 'solo_singer',
#    'birth_name': 'Ernest Nsimbi',
#    'native_name': 'Lupiazitta',
#    'birth_place': 'Uganda < ref name=hipipo/ >',
#    'death_date': '< !--  (death date 1st) -- >',
#    'genre': 'Hip hop',
#    'occupation': 'Rapper, musician, songwriter',
#    'instrument': 'Drums, cymbals',
#    'years_active': '2007present',
#    'label': 'Baboon Forest Entertainment',
#    'website': '< !--  -- >'},
#   ['Uganda',
#    'Hip hop music',
#    'rapping',
#    'hip hop',
#    'Makerere University',
#    'Luganda',
#    'Luganda',
#    'Yoweri Museveni',
#    'Oxfam',
#    'Uganda Wildlife Authority',
#    'Ministry of Health (Uganda)',
#    'Buzz Teeniez Awards',
#    'Makerere University',
#    'Mukono District',
#    'Kampala',
#    'Kawempe',
#    'Ugandan Bush War',
#    'Category:1986 births',
#    'Category:Living people',
#    'Category:Makerere University alumni',
#    'Category:Ugandan rappers'],
#   {'name': [],
#    'image': [],
#    'image_size': [],
#    'landscape': [],
#    'alt': [],
#    'caption': [],
#    'background': [],
#    'birth_name': [],
#    'native_name': [],
#    'native_name_lang': [],
#    'alias': [],
#    'birth_date': [],
#    'birth_place': ['Uganda'],
#    'origin': [],
#    'death_date': [],
#    'death_place': [],
#    'genre': ['Hip hop music'],
#    'occupation': ['rapping'],
#    'instrument': [],
#    'years_active': [],
#    'label': [],
#    'associated_acts': [],
#    'website': []},
#   '2019-01-17T02:43:54Z',
#   7051),
#  ('DJ Bitman',
#   {'name': 'DJ Bitman',
#    'background': 'non_vocal_instrumentalist',
#    'birth_name': 'José Antonio Bravo',
#    'alias': 'Bitman, Latin Bitman, Bitman and Roban',
#    'origin': 'Arica, Chile',
#    'genre': 'Electronica, hip hop, funk',
#    'occupation': 'DJ, record producer',
#    'years_active': '1999–present',
#    'label': 'Nacional Records, Feria Music',
#    'associated_acts': 'Eric  " Bobo "  Correa, Bitman and Roban, RVSB.',
#    'website': 'Latin Bitman Official website'},
#   ['Arica',
#    'Chile',
#    'Electronica',
#    'hip hop music',
#    'funk',
#    'Disc jockey',
#    'record producer',
#    'Nacional Records',
#    'Feria Music',
#    'Eric_%22Bobo%22_Correa',
#    'electronic music',
#    'DJ',
#    'Sen Dog',
#    'Eric_%22Bobo%22_Correa',
#    'Cypress Hill',
#    'Francisca Valenzuela',
#    'DJ Raff',
#    'Los Tetas',
#    'Anita Tijoux',
#    'Lollapalooza',
#    'Lollapalooza Chile',
#    'EA Sports',
#    'FIFA 07',
#    'FIFA 09',
#    '2010 FIFA World Cup South Africa (video game)',
#    'The Chicas Project',
#    'Arica',
#    'Arica y Parinacota Region',
#    'Chile',
#    'Hip Hop',
#    'Los Tres',
#    'Tiro de Gracia',
#    'Los Tetas',
#    'Double bass',
#    'Marimba',
#    'Guitar',
#    'Piano',
#    'Hammond organ',
#    'jazz',
#    'bossa nova',
#    'funk',
#    'chachachá',
#    'mambo (music)',
#    'Francisca Valenzuela',
#    'Cypress Hill',
#    'Aftershock (2012 film)',
#    'Crystal Fairy  &  the Magical Cactus',
#    'From Prada to Nada (2011)',
#    'Category:1975 births',
#    'Category:Living people',
#    'Category:Chilean musicians',
#    'Category:German techno musicians',
#    'Category:People from Arica',
#    'Category:Nacional Records artists'],
#   {'name': [],
#    'background': [],
#    'birth_name': [],
#    'alias': [],
#    'birth_date': [],
#    'origin': ['Arica', 'Chile'],
#    'genre': ['Electronica', 'hip hop music', 'funk'],
#    'occupation': ['Disc jockey', 'record producer'],
#    'years_active': [],
#    'label': ['Nacional Records', 'Feria Music'],
#    'associated_acts': ['Eric_%22Bobo%22_Correa'],
#    'website': []},
#   '2017-09-02T23:37:51Z',
#   4902)]

# %%
from multiprocessing import Pool 
import tqdm 

# List of lists to single list
from itertools import chain

# Sending keyword arguments in map
from functools import partial

# %%
os.cpu_count()
# Out:
# 12

# %% [markdown]
# Adjust the number of processes based on your cpu count.

# %% [markdown]
# ## Searching for Every Book on Wikipedia
#
# The code below searches all of Wikipedia for every book article!
#
# We create a `Pool` with the number of processes and then call `map` with the `(service, tasks)`. `map` applies a function to each item in an iterable (such as a list). The books for each partition are saved to a json file on disk.

# %%
# Create a pool of workers to execute processes
pool = Pool(processes = 10)

start = timer()

# Map (service, tasks), applies function to each partition
results = pool.map(find_artist, files_list)

pool.close()
pool.join()

end = timer()
print(f'{end - start} seconds elapsed.')
# Out:
# 18250.96685815099 seconds elapsed.

# %% [markdown]
# This took about 2.5 hours instead of 15! We can definitely see the advantages to parallelization.

# %% [markdown]
# #### Monitoring Progress
#
# If you want to monitor the state of your sytem as the code runs, you can type `htop` at the command line. This comprehensive [process viewer](https://hisham.hm/htop/) shows the running processes and the memory / CPU taken up by the processes. For example, when I type `htop`, I get the following information:
#
# ![](images/top_parallel_processes.PNG)

# %% [markdown]
# I can see that I'm running 16 processes of Python and 16 processes of bzcat. The top of the image shows that all 16 cores are being run at near 100% of the CPU. This information can be useful for determining if you are close to using all system memory. With so many processes running, it is possible to use up all system memory. In this case you might want to use fewer processes or reduce memory consumption of other running programs.

# %% [markdown]
# #### Alternative Code with Progress Bar
#
# If you would like a progress bar to appear in your Jupyter Notebook as you run the operation, you can use the code below. This wraps `tqdm` around a call to `imap_unordered`. `imap` does the same basic job as `map` except the results are returned as they finish instead of all at once. The end result will still be the exact same, but sometimes you want te results to be returned as they are completed instead of once at the end. There are some situations where you'd want to use `imap` instead of `map`, and [this Stack Overflow answer](https://stackoverflow.com/a/26521507/5755357) does a great job of explaining the differences.
#
#  The `tqdm` library can be used to track progress (the resulting widgets may not show up correclty in a static Jupyter Notebook).

# %%
# start = timer()
# pool = Pool(processes = 8)
# results = []

# # Run partitions in parallel
# for x in tqdm.tqdm_notebook(pool.imap_unordered(find_books, partitions), total = len(partitions)):
#     results.append(x)
    
# pool.close()
# pool.join()

# end = timer()

# %% [markdown]
# ### Join Data Together
#
# After creating the separate files, each one containing the books from one partition, we can join them together into a single list by reading them from disk. For this task, we'll use `multithreading` to read in the files in parallel. Again, we'll need a service, this time the function `read_data`, and tasks, all the `saved_files`, each of which contains the books for one partition.

# %%
def read_data(file_path):
    """Read in json data from `file_path`"""
    
    data = []
    
    # Open the file and load in json
    with open(file_path, 'r') as fin:
        for l in fin.readlines():
            data.append(json.loads(l))
            
    return data

# %% [markdown]
# To use `multithreading` instead of `multiprocessing`, we import `Pool` from the [`multiprocessing.dummy` module](https://docs.python.org/3/library/multiprocessing.html#module-multiprocessing.dummy). Then we create a `Threadpool` of workers and `map` the `tasks` to the `service`. This will return a lists of lists that we can flatten to a single list using `chain` from itertools.  The final result is a single list containing the information for all the book articles. These are then saved for further analysis.

# %%
from multiprocessing.dummy import Pool as Threadpool
from itertools import chain

start = timer()

# List of files to read in
saved_files = glob('data/*')

# Create a threadpool for reading in files
threadpool = Threadpool(processes = 10)

# Read in the files as a list of lists
results = threadpool.map(read_data, saved_files)

# Flatten the list of lists to a single list
book_list = list(chain(*results))

end = timer()

print(f'Found {len(book_list)} books in {round(end - start)} seconds.')
# Out:
# Found 64822 books in 5 seconds.

# %% [markdown]
# The code below saves all the books as a single file.

# %%
if not os.path.exists(os.getcwd() + 'found_artists_filtered.ndjson'):
    with open('found_artists_filtered.ndjson', 'wt') as fout:
        for book in book_list:
             fout.write(json.dumps(book) + '\n')
    print('Books saved.')
else:
    print('Files already saved.')
# Out:
# Books saved.
